# %%
# this file is for pruned model fine-tune training

# %%
#import useful package
from __future__ import print_function
import os
import argparse
import shutil

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


import torchvision
from torchvision import datasets, transforms

import models
from torchinfo import summary
from collections import OrderedDict
from matplotlib import pyplot as plt

# %%
# set up device 
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
# Out:
# cuda

# %%
# data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
train_loader = torch.utils.data.DataLoader(
    trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
test_loader = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#model after pruning
path = './checkpoint/pruned.pth.tar'
checkpoint = torch.load(path)
model = models.resnet(cfg=checkpoint['cfg'])
model.load_state_dict(checkpoint['state_dict'])
# Out:
# <All keys matched successfully>

# %%
#model paramter display
params = sum(p.numel() for p in model.parameters())
print(params)
summary(model, input_size=(1,3, 32, 32))
# Out:
# 4558938
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# resnet                                   [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 64, 32, 32]           1,728
# ├─Sequential: 1-2                        [1, 64, 32, 32]           --
# │    └─FusionBlock: 2-1                  [1, 64, 32, 32]           --
# │    │    └─Sequential: 3-1              [1, 64, 32, 32]           4,928
# │    │    └─BatchNorm2d: 3-2             [1, 64, 32, 32]           128
# │    │    └─ReLU: 3-3                    [1, 64, 32, 32]           --
# │    │    └─Sequential: 3-4              [1, 64, 32, 32]           4,928
# │    │    └─BatchNorm2d: 3-5             [1, 64, 32, 32]           128
# │    │    └─ReLU: 3-6                    [1, 64, 32, 32]           --
# │    └─FusionBlock: 2-2                  [1, 64, 32, 32]           --
# │    │    └─Sequential: 3-7              [1, 64, 32, 32]           4,928
# │    │    └─BatchNorm2d: 3-8             [1, 64, 32, 32]           128
# │    │    └─ReLU: 3-9                    [1, 64, 32, 32]           --
# │    │    └─Sequential: 3-10             [1, 64, 32, 32]           4,928
# │    │    └─BatchNorm2d: 3-11            [1, 64, 32, 32]           128
# │    │    └─Sequential: 3-12             [1, 64, 32, 32]           102,528
# │    │    └─ReLU: 3-13                   [1, 64, 32, 32]           --
# ├─Sequential: 1-3                        [1, 128, 16, 16]          --
# │    └─FusionBlock: 2-3                  [1, 128, 16, 16]          --
# │    │    └─Sequential: 3-14             [1, 128, 16, 16]          9,216
# │    │    └─BatchNorm2d: 3-15            [1, 128, 16, 16]          256
# │    │    └─ReLU: 3-16                   [1, 128, 16, 16]          --
# │    │    └─Sequential: 3-17             [1, 128, 16, 16]          18,048
# │    │    └─BatchNorm2d: 3-18            [1, 128, 16, 16]          256
# │    │    └─Sequential: 3-19             [1, 128, 16, 16]          8,192
# │    │    └─ReLU: 3-20                   [1, 128, 16, 16]          --
# │    └─FusionBlock: 2-4                  [1, 128, 16, 16]          --
# │    │    └─Sequential: 3-21             [1, 128, 16, 16]          18,048
# │    │    └─BatchNorm2d: 3-22            [1, 128, 16, 16]          256
# │    │    └─ReLU: 3-23                   [1, 128, 16, 16]          --
# │    │    └─Sequential: 3-24             [1, 128, 16, 16]          18,048
# │    │    └─BatchNorm2d: 3-25            [1, 128, 16, 16]          256
# │    │    └─Sequential: 3-26             [1, 128, 16, 16]          409,856
# │    │    └─ReLU: 3-27                   [1, 128, 16, 16]          --
# ├─Sequential: 1-4                        [1, 256, 8, 8]            --
# │    └─BasicBlock: 2-5                   [1, 256, 8, 8]            --
# │    │    └─BatchNorm2d: 3-28            [1, 128, 16, 16]          256
# │    │    └─channel_selection: 3-29      [1, 123, 16, 16]          128
# │    │    └─ReLU: 3-30                   [1, 123, 16, 16]          --
# │    │    └─Conv2d: 3-31                 [1, 255, 8, 8]            282,285
# │    │    └─BatchNorm2d: 3-32            [1, 255, 8, 8]            510
# │    │    └─ReLU: 3-33                   [1, 255, 8, 8]            --
# │    │    └─Conv2d: 3-34                 [1, 256, 8, 8]            587,520
# │    │    └─Sequential: 3-35             [1, 256, 8, 8]            32,768
# │    └─BasicBlock: 2-6                   [1, 256, 8, 8]            --
# │    │    └─BatchNorm2d: 3-36            [1, 256, 8, 8]            512
# │    │    └─channel_selection: 3-37      [1, 220, 8, 8]            256
# │    │    └─ReLU: 3-38                   [1, 220, 8, 8]            --
# │    │    └─Conv2d: 3-39                 [1, 254, 8, 8]            502,920
# │    │    └─BatchNorm2d: 3-40            [1, 254, 8, 8]            508
# │    │    └─ReLU: 3-41                   [1, 254, 8, 8]            --
# │    │    └─Conv2d: 3-42                 [1, 256, 8, 8]            585,216
# ├─Sequential: 1-5                        [1, 512, 4, 4]            --
# │    └─BasicBlock: 2-7                   [1, 512, 4, 4]            --
# │    │    └─BatchNorm2d: 3-43            [1, 256, 8, 8]            512
# │    │    └─channel_selection: 3-44      [1, 199, 8, 8]            256
# │    │    └─ReLU: 3-45                   [1, 199, 8, 8]            --
# │    │    └─Conv2d: 3-46                 [1, 167, 4, 4]            299,097
# │    │    └─BatchNorm2d: 3-47            [1, 167, 4, 4]            334
# │    │    └─ReLU: 3-48                   [1, 167, 4, 4]            --
# │    │    └─Conv2d: 3-49                 [1, 512, 4, 4]            769,536
# │    │    └─Sequential: 3-50             [1, 512, 4, 4]            131,072
# │    └─BasicBlock: 2-8                   [1, 512, 4, 4]            --
# │    │    └─BatchNorm2d: 3-51            [1, 512, 4, 4]            1,024
# │    │    └─channel_selection: 3-52      [1, 68, 4, 4]             512
# │    │    └─ReLU: 3-53                   [1, 68, 4, 4]             --
# │    │    └─Conv2d: 3-54                 [1, 144, 4, 4]            88,128
# │    │    └─BatchNorm2d: 3-55            [1, 144, 4, 4]            288
# │    │    └─ReLU: 3-56                   [1, 144, 4, 4]            --
# │    │    └─Conv2d: 3-57                 [1, 512, 4, 4]            663,552
# ├─BatchNorm2d: 1-6                       [1, 512, 4, 4]            1,024
# ├─channel_selection: 1-7                 [1, 329, 4, 4]            512
# ├─ReLU: 1-8                              [1, 329, 4, 4]            --
# ├─AvgPool2d: 1-9                         [1, 329, 1, 1]            --
# ├─Linear: 1-10                           [1, 10]                   3,300
# ==========================================================================================
# Total params: 4,558,938
# Trainable params: 4,558,938
# Non-trainable params: 0
# Total mult-adds (M): 407.84
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 17.17
# Params size (MB): 18.24
# Estimated Total Size (MB): 35.42
# ==========================================================================================

# %%
# loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1,momentum=0.9, weight_decay=5e-4)

# %%
#training function
def train(epoch,train_loss_list,train_acc_list):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        
        data, target = data.to(device), target.to(device)
        
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        train_loss +=loss.item()
        
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()
        
        loss.backward()
          
        optimizer.step()
        
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()/len(data)))
                  
    train_loss /= len(train_loader.dataset)
    train_loss_list.append(train_loss)
    train_acc = correct / len(train_loader.dataset)
    train_acc_list.append(train_acc)
    
    print('\nTraining Set: Average loss: {:.4f},Accuracy: {}/{} ({:.1f}%)\n'.format(
            train_loss, correct, len(train_loader.dataset), 100. * train_acc))

# test function
def test(test_loss_list,test_acc_list):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:

            data, target = data.to(device), target.to(device)
            output = model(data)

            loss = criterion(output, target)
            test_loss += loss.item() # sum up batch loss

            pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.data.view_as(pred)).cpu().sum()

        test_loss /= len(test_loader.dataset)
        test_loss_list.append(test_loss)
        test_acc = correct / float(len(test_loader.dataset))
        test_acc_list.append(test_acc)
        
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset),100. *test_acc))
        
        return correct / float(len(test_loader.dataset))

def save_checkpoint(state, is_best, filepath):
    torch.save(state, os.path.join(filepath, 'finetune.pth.tar'))
    if is_best:
        print('\n!!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!! \n')
        shutil.copyfile(os.path.join(filepath, 'finetune.pth.tar'), os.path.join(filepath, 'finetune_model_best.pth.tar'))

# %%
from matplotlib import pyplot as plt

# %%
plt.figure()
ax=plt.axes()
plt.xlabel('Round')  
plt.ylabel('Loss')   

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(test_loss)), test_loss, label="test loss")
plt.legend(loc='upper right')
plt.title("loss_curve")
plt.savefig("./checkpoint/finetune/finetune_loss_curve.png")

# %%
plt.figure()
ax=plt.axes()
plt.xlabel('Round')    
plt.ylabel('acc')     

plt.plot(range(len(train_acc)), train_acc, label="train acc")
plt.plot(range(len(test_acc)), test_acc, label="test acc")
plt.legend(loc='upper right')
plt.title("acc_curve")
plt.savefig("./checkpoint/finetune/finetune_acc_curve.png")

# %%
best_prec1 = 0.

import time

if not os.path.isdir('checkpoint'):
    os.mkdir('checkpoint')

train_loss = []
train_acc = []
test_loss = []
test_acc = []

# training 
for epoch in range(0, 100):
    if epoch in [30, 50]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1
        
    start_time = time.time()
    
    train(epoch,train_loss,train_acc)
    prec1 = test(test_loss,test_acc)
    
    end_time = time.time()
    
    interval = end_time - start_time
    print('One epoch time cost: {:.3f} s \n'.format(interval))
   
    
    #scheduler.step()
    
    is_best = prec1 > best_prec1
    best_prec1 = max(prec1, best_prec1)
    
    save_checkpoint({
        'epoch': epoch + 1,
        'state_dict': model.state_dict(),
        'best_prec1': best_prec1,
        'optimizer': optimizer.state_dict(),
    }, is_best, filepath='./checkpoint/finetune')
    
    print('----------------------------------------------- \n')

    
print("Best accuracy: "+str(best_prec1))

# write loss data to txt file
savepath = os.path.join('./checkpoint/finetune', "finetune_train_loss.txt")
with open(savepath, "w") as fp:
    for data in train_loss:
        fp.write(str(data)+"\n")
    
savepath = os.path.join('./checkpoint/finetune', "finetune_train_acc.txt")
with open(savepath, "w") as fp:
       for data in train_acc:
        fp.write(str(data)+"\n")
    
savepath = os.path.join('./checkpoint/finetune', "finetune_test_loss.txt")
with open(savepath, "w") as fp:
    for data in test_loss:
        fp.write(str(data)+"\n")
    
savepath = os.path.join('./checkpoint/finetune', "finetune_test_acc.txt")
with open(savepath, "w") as fp:
    for data in test_acc:
        fp.write(str(data)+"\n")
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 0.026661
# Train Epoch: 0 [12800/50000 (25.6%)]	Loss: 0.014692
# Train Epoch: 0 [25600/50000 (51.2%)]	Loss: 0.014431
# Train Epoch: 0 [38400/50000 (76.7%)]	Loss: 0.012937
#
# Training Set: Average loss: 0.0138,Accuracy: 16373/50000 (32.7%)
#
#
# Test set: Average loss: 0.0182, Accuracy: 3648/10000 (36.5%)
#
# One epoch time cost: 43.732 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 0.011058
# Train Epoch: 1 [12800/50000 (25.6%)]	Loss: 0.010722
# Train Epoch: 1 [25600/50000 (51.2%)]	Loss: 0.009017
# Train Epoch: 1 [38400/50000 (76.7%)]	Loss: 0.009092
#
# Training Set: Average loss: 0.0101,Accuracy: 26251/50000 (52.5%)
#
#
# Test set: Average loss: 0.0140, Accuracy: 4925/10000 (49.2%)
#
# One epoch time cost: 44.267 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.009998
# Train Epoch: 2 [12800/50000 (25.6%)]	Loss: 0.008014
# Train Epoch: 2 [25600/50000 (51.2%)]	Loss: 0.008481
# Train Epoch: 2 [38400/50000 (76.7%)]	Loss: 0.007291
#
# Training Set: Average loss: 0.0082,Accuracy: 30954/50000 (61.9%)
#
#
# Test set: Average loss: 0.0111, Accuracy: 6108/10000 (61.1%)
#
# One epoch time cost: 44.780 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.007665
# Train Epoch: 3 [12800/50000 (25.6%)]	Loss: 0.007017
# Train Epoch: 3 [25600/50000 (51.2%)]	Loss: 0.006263
# Train Epoch: 3 [38400/50000 (76.7%)]	Loss: 0.006159
#
# Training Set: Average loss: 0.0070,Accuracy: 34107/50000 (68.2%)
#
#
# Test set: Average loss: 0.0113, Accuracy: 6358/10000 (63.6%)
#
# One epoch time cost: 45.376 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.007005
# Train Epoch: 4 [12800/50000 (25.6%)]	Loss: 0.006027
# Train Epoch: 4 [25600/50000 (51.2%)]	Loss: 0.005638
# Train Epoch: 4 [38400/50000 (76.7%)]	Loss: 0.006045
#
# Training Set: Average loss: 0.0061,Accuracy: 36501/50000 (73.0%)
#
#
# Test set: Average loss: 0.0096, Accuracy: 6819/10000 (68.2%)
#
# One epoch time cost: 46.090 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.004396
# Train Epoch: 5 [12800/50000 (25.6%)]	Loss: 0.006088
# Train Epoch: 5 [25600/50000 (51.2%)]	Loss: 0.005552
# Train Epoch: 5 [38400/50000 (76.7%)]	Loss: 0.005937
#
# Training Set: Average loss: 0.0055,Accuracy: 37744/50000 (75.5%)
#
#
# Test set: Average loss: 0.0082, Accuracy: 7255/10000 (72.5%)
#
# One epoch time cost: 46.142 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.003906
# Train Epoch: 6 [12800/50000 (25.6%)]	Loss: 0.006187
# Train Epoch: 6 [25600/50000 (51.2%)]	Loss: 0.006099
# Train Epoch: 6 [38400/50000 (76.7%)]	Loss: 0.005436
#
# Training Set: Average loss: 0.0050,Accuracy: 38943/50000 (77.9%)
#
#
# Test set: Average loss: 0.0072, Accuracy: 7605/10000 (76.1%)
#
# One epoch time cost: 46.208 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.004749
# Train Epoch: 7 [12800/50000 (25.6%)]	Loss: 0.004666
# Train Epoch: 7 [25600/50000 (51.2%)]	Loss: 0.007292
# Train Epoch: 7 [38400/50000 (76.7%)]	Loss: 0.003899
#
# Training Set: Average loss: 0.0048,Accuracy: 39612/50000 (79.2%)
#
#
# Test set: Average loss: 0.0087, Accuracy: 7154/10000 (71.5%)
#
# One epoch time cost: 46.375 s
#
# -----------------------------------------------
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.004018
# Train Epoch: 8 [12800/50000 (25.6%)]	Loss: 0.005347
# Train Epoch: 8 [25600/50000 (51.2%)]	Loss: 0.004089
# Train Epoch: 8 [38400/50000 (76.7%)]	Loss: 0.005567
#
# Training Set: Average loss: 0.0045,Accuracy: 40313/50000 (80.6%)
#
#
# Test set: Average loss: 0.0065, Accuracy: 7837/10000 (78.4%)
#
# One epoch time cost: 45.829 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.004748
# Train Epoch: 9 [12800/50000 (25.6%)]	Loss: 0.004899
# Train Epoch: 9 [25600/50000 (51.2%)]	Loss: 0.005080
# Train Epoch: 9 [38400/50000 (76.7%)]	Loss: 0.005103
#
# Training Set: Average loss: 0.0043,Accuracy: 40448/50000 (80.9%)
#
#
# Test set: Average loss: 0.0055, Accuracy: 8115/10000 (81.2%)
#
# One epoch time cost: 45.993 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.003708
# Train Epoch: 10 [12800/50000 (25.6%)]	Loss: 0.005747
# Train Epoch: 10 [25600/50000 (51.2%)]	Loss: 0.003485
# Train Epoch: 10 [38400/50000 (76.7%)]	Loss: 0.003782
#
# Training Set: Average loss: 0.0041,Accuracy: 41047/50000 (82.1%)
#
#
# Test set: Average loss: 0.0068, Accuracy: 7719/10000 (77.2%)
#
# One epoch time cost: 46.239 s
#
# -----------------------------------------------
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.004177
# Train Epoch: 11 [12800/50000 (25.6%)]	Loss: 0.003885
# Train Epoch: 11 [25600/50000 (51.2%)]	Loss: 0.002622
# Train Epoch: 11 [38400/50000 (76.7%)]	Loss: 0.003737
#
# Training Set: Average loss: 0.0040,Accuracy: 41211/50000 (82.4%)
#
#
# Test set: Average loss: 0.0058, Accuracy: 8065/10000 (80.7%)
#
# One epoch time cost: 46.022 s
#
# -----------------------------------------------
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.004442
# Train Epoch: 12 [12800/50000 (25.6%)]	Loss: 0.003035
# Train Epoch: 12 [25600/50000 (51.2%)]	Loss: 0.003454
# Train Epoch: 12 [38400/50000 (76.7%)]	Loss: 0.003876
#
# Training Set: Average loss: 0.0039,Accuracy: 41393/50000 (82.8%)
#
#
# Test set: Average loss: 0.0085, Accuracy: 7391/10000 (73.9%)
#
# One epoch time cost: 45.852 s
#
# -----------------------------------------------
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.003244
# Train Epoch: 13 [12800/50000 (25.6%)]	Loss: 0.002938
# Train Epoch: 13 [25600/50000 (51.2%)]	Loss: 0.002904
# Train Epoch: 13 [38400/50000 (76.7%)]	Loss: 0.003886
#
# Training Set: Average loss: 0.0038,Accuracy: 41628/50000 (83.3%)
#
#
# Test set: Average loss: 0.0073, Accuracy: 7604/10000 (76.0%)
#
# One epoch time cost: 45.933 s
#
# -----------------------------------------------
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.003045
# Train Epoch: 14 [12800/50000 (25.6%)]	Loss: 0.004147
# Train Epoch: 14 [25600/50000 (51.2%)]	Loss: 0.003136
# Train Epoch: 14 [38400/50000 (76.7%)]	Loss: 0.003901
#
# Training Set: Average loss: 0.0038,Accuracy: 41836/50000 (83.7%)
#
#
# Test set: Average loss: 0.0068, Accuracy: 7782/10000 (77.8%)
#
# One epoch time cost: 46.285 s
#
# -----------------------------------------------
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.003858
# Train Epoch: 15 [12800/50000 (25.6%)]	Loss: 0.004517
# Train Epoch: 15 [25600/50000 (51.2%)]	Loss: 0.004186
# Train Epoch: 15 [38400/50000 (76.7%)]	Loss: 0.003579
#
# Training Set: Average loss: 0.0037,Accuracy: 41906/50000 (83.8%)
#
#
# Test set: Average loss: 0.0067, Accuracy: 7822/10000 (78.2%)
#
# One epoch time cost: 46.004 s
#
# -----------------------------------------------
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.003424
# Train Epoch: 16 [12800/50000 (25.6%)]	Loss: 0.003463
# Train Epoch: 16 [25600/50000 (51.2%)]	Loss: 0.003530
# Train Epoch: 16 [38400/50000 (76.7%)]	Loss: 0.004383
#
# Training Set: Average loss: 0.0036,Accuracy: 42019/50000 (84.0%)
#
#
# Test set: Average loss: 0.0064, Accuracy: 7881/10000 (78.8%)
#
# One epoch time cost: 45.770 s
#
# -----------------------------------------------
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.002507
# Train Epoch: 17 [12800/50000 (25.6%)]	Loss: 0.003824
# Train Epoch: 17 [25600/50000 (51.2%)]	Loss: 0.002734
# Train Epoch: 17 [38400/50000 (76.7%)]	Loss: 0.002871
#
# Training Set: Average loss: 0.0035,Accuracy: 42279/50000 (84.6%)
#
#
# Test set: Average loss: 0.0068, Accuracy: 7757/10000 (77.6%)
#
# One epoch time cost: 45.635 s
#
# -----------------------------------------------
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.003439
# Train Epoch: 18 [12800/50000 (25.6%)]	Loss: 0.003457
# Train Epoch: 18 [25600/50000 (51.2%)]	Loss: 0.003260
# Train Epoch: 18 [38400/50000 (76.7%)]	Loss: 0.004082
#
# Training Set: Average loss: 0.0035,Accuracy: 42188/50000 (84.4%)
#
#
# Test set: Average loss: 0.0055, Accuracy: 8159/10000 (81.6%)
#
# One epoch time cost: 45.929 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.003275
# Train Epoch: 19 [12800/50000 (25.6%)]	Loss: 0.003781
# Train Epoch: 19 [25600/50000 (51.2%)]	Loss: 0.002501
# Train Epoch: 19 [38400/50000 (76.7%)]	Loss: 0.004062
#
# Training Set: Average loss: 0.0034,Accuracy: 42438/50000 (84.9%)
#
#
# Test set: Average loss: 0.0063, Accuracy: 8008/10000 (80.1%)
#
# One epoch time cost: 45.894 s
#
# -----------------------------------------------
#
# Train Epoch: 20 [0/50000 (0.0%)]	Loss: 0.002328
# Train Epoch: 20 [12800/50000 (25.6%)]	Loss: 0.003364
# Train Epoch: 20 [25600/50000 (51.2%)]	Loss: 0.003981
# Train Epoch: 20 [38400/50000 (76.7%)]	Loss: 0.004073
#
# Training Set: Average loss: 0.0034,Accuracy: 42470/50000 (84.9%)
#
#
# Test set: Average loss: 0.0057, Accuracy: 8135/10000 (81.3%)
#
# One epoch time cost: 45.692 s
#
# -----------------------------------------------
#
# Train Epoch: 21 [0/50000 (0.0%)]	Loss: 0.003038
# Train Epoch: 21 [12800/50000 (25.6%)]	Loss: 0.003164
# Train Epoch: 21 [25600/50000 (51.2%)]	Loss: 0.003509
# Train Epoch: 21 [38400/50000 (76.7%)]	Loss: 0.002657
#
# Training Set: Average loss: 0.0034,Accuracy: 42524/50000 (85.0%)
#
#
# Test set: Average loss: 0.0058, Accuracy: 8051/10000 (80.5%)
#
# One epoch time cost: 46.200 s
#
# -----------------------------------------------
#
# Train Epoch: 22 [0/50000 (0.0%)]	Loss: 0.003291
# Train Epoch: 22 [12800/50000 (25.6%)]	Loss: 0.002588
# Train Epoch: 22 [25600/50000 (51.2%)]	Loss: 0.002927
# Train Epoch: 22 [38400/50000 (76.7%)]	Loss: 0.002452
#
# Training Set: Average loss: 0.0033,Accuracy: 42735/50000 (85.5%)
#
#
# Test set: Average loss: 0.0064, Accuracy: 7916/10000 (79.2%)
#
# One epoch time cost: 45.999 s
#
# -----------------------------------------------
#
# Train Epoch: 23 [0/50000 (0.0%)]	Loss: 0.003053
# Train Epoch: 23 [12800/50000 (25.6%)]	Loss: 0.003351
# Train Epoch: 23 [25600/50000 (51.2%)]	Loss: 0.002905
# Train Epoch: 23 [38400/50000 (76.7%)]	Loss: 0.002894
#
# Training Set: Average loss: 0.0033,Accuracy: 42698/50000 (85.4%)
#
#
# Test set: Average loss: 0.0055, Accuracy: 8157/10000 (81.6%)
#
# One epoch time cost: 45.819 s
#
# -----------------------------------------------
#
# Train Epoch: 24 [0/50000 (0.0%)]	Loss: 0.003050
# Train Epoch: 24 [12800/50000 (25.6%)]	Loss: 0.002941
# Train Epoch: 24 [25600/50000 (51.2%)]	Loss: 0.003508
# Train Epoch: 24 [38400/50000 (76.7%)]	Loss: 0.003058
#
# Training Set: Average loss: 0.0033,Accuracy: 42906/50000 (85.8%)
#
#
# Test set: Average loss: 0.0054, Accuracy: 8223/10000 (82.2%)
#
# One epoch time cost: 46.044 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 25 [0/50000 (0.0%)]	Loss: 0.002810
# Train Epoch: 25 [12800/50000 (25.6%)]	Loss: 0.003580
# Train Epoch: 25 [25600/50000 (51.2%)]	Loss: 0.003812
# Train Epoch: 25 [38400/50000 (76.7%)]	Loss: 0.003588
#
# Training Set: Average loss: 0.0033,Accuracy: 42819/50000 (85.6%)
#
#
# Test set: Average loss: 0.0086, Accuracy: 7351/10000 (73.5%)
#
# One epoch time cost: 46.026 s
#
# -----------------------------------------------
#
# Train Epoch: 26 [0/50000 (0.0%)]	Loss: 0.003569
# Train Epoch: 26 [12800/50000 (25.6%)]	Loss: 0.003134
# Train Epoch: 26 [25600/50000 (51.2%)]	Loss: 0.002545
# Train Epoch: 26 [38400/50000 (76.7%)]	Loss: 0.002537
#
# Training Set: Average loss: 0.0032,Accuracy: 42951/50000 (85.9%)
#
#
# Test set: Average loss: 0.0052, Accuracy: 8291/10000 (82.9%)
#
# One epoch time cost: 45.824 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 27 [0/50000 (0.0%)]	Loss: 0.002665
# Train Epoch: 27 [12800/50000 (25.6%)]	Loss: 0.003801
# Train Epoch: 27 [25600/50000 (51.2%)]	Loss: 0.003777
# Train Epoch: 27 [38400/50000 (76.7%)]	Loss: 0.002647
#
# Training Set: Average loss: 0.0032,Accuracy: 42941/50000 (85.9%)
#
#
# Test set: Average loss: 0.0054, Accuracy: 8269/10000 (82.7%)
#
# One epoch time cost: 45.663 s
#
# -----------------------------------------------
#
# Train Epoch: 28 [0/50000 (0.0%)]	Loss: 0.001839
# Train Epoch: 28 [12800/50000 (25.6%)]	Loss: 0.003576
# Train Epoch: 28 [25600/50000 (51.2%)]	Loss: 0.002803
# Train Epoch: 28 [38400/50000 (76.7%)]	Loss: 0.002337
#
# Training Set: Average loss: 0.0032,Accuracy: 43010/50000 (86.0%)
#
#
# Test set: Average loss: 0.0047, Accuracy: 8410/10000 (84.1%)
#
# One epoch time cost: 46.158 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 29 [0/50000 (0.0%)]	Loss: 0.002111
# Train Epoch: 29 [12800/50000 (25.6%)]	Loss: 0.003044
# Train Epoch: 29 [25600/50000 (51.2%)]	Loss: 0.004395
# Train Epoch: 29 [38400/50000 (76.7%)]	Loss: 0.003463
#
# Training Set: Average loss: 0.0032,Accuracy: 43094/50000 (86.2%)
#
#
# Test set: Average loss: 0.0056, Accuracy: 8172/10000 (81.7%)
#
# One epoch time cost: 46.033 s
#
# -----------------------------------------------
#
# Train Epoch: 30 [0/50000 (0.0%)]	Loss: 0.002441
# Train Epoch: 30 [12800/50000 (25.6%)]	Loss: 0.002946
# Train Epoch: 30 [25600/50000 (51.2%)]	Loss: 0.002370
# Train Epoch: 30 [38400/50000 (76.7%)]	Loss: 0.001497
#
# Training Set: Average loss: 0.0019,Accuracy: 45889/50000 (91.8%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9068/10000 (90.7%)
#
# One epoch time cost: 46.031 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 31 [0/50000 (0.0%)]	Loss: 0.001449
# Train Epoch: 31 [12800/50000 (25.6%)]	Loss: 0.001752
# Train Epoch: 31 [25600/50000 (51.2%)]	Loss: 0.001612
# Train Epoch: 31 [38400/50000 (76.7%)]	Loss: 0.001494
#
# Training Set: Average loss: 0.0015,Accuracy: 46677/50000 (93.4%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9121/10000 (91.2%)
#
# One epoch time cost: 46.003 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 32 [0/50000 (0.0%)]	Loss: 0.001182
# Train Epoch: 32 [12800/50000 (25.6%)]	Loss: 0.001430
# Train Epoch: 32 [25600/50000 (51.2%)]	Loss: 0.001371
# Train Epoch: 32 [38400/50000 (76.7%)]	Loss: 0.001266
#
# Training Set: Average loss: 0.0013,Accuracy: 47079/50000 (94.2%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9127/10000 (91.3%)
#
# One epoch time cost: 45.966 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 33 [0/50000 (0.0%)]	Loss: 0.001340
# Train Epoch: 33 [12800/50000 (25.6%)]	Loss: 0.002060
# Train Epoch: 33 [25600/50000 (51.2%)]	Loss: 0.000773
# Train Epoch: 33 [38400/50000 (76.7%)]	Loss: 0.001168
#
# Training Set: Average loss: 0.0013,Accuracy: 47294/50000 (94.6%)
#
#
# Test set: Average loss: 0.0025, Accuracy: 9162/10000 (91.6%)
#
# One epoch time cost: 45.973 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 34 [0/50000 (0.0%)]	Loss: 0.001588
# Train Epoch: 34 [12800/50000 (25.6%)]	Loss: 0.002463
# Train Epoch: 34 [25600/50000 (51.2%)]	Loss: 0.001258
# Train Epoch: 34 [38400/50000 (76.7%)]	Loss: 0.001359
#
# Training Set: Average loss: 0.0012,Accuracy: 47518/50000 (95.0%)
#
#
# Test set: Average loss: 0.0025, Accuracy: 9164/10000 (91.6%)
#
# One epoch time cost: 45.989 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 35 [0/50000 (0.0%)]	Loss: 0.000888
# Train Epoch: 35 [12800/50000 (25.6%)]	Loss: 0.000647
# Train Epoch: 35 [25600/50000 (51.2%)]	Loss: 0.000841
# Train Epoch: 35 [38400/50000 (76.7%)]	Loss: 0.000984
#
# Training Set: Average loss: 0.0011,Accuracy: 47695/50000 (95.4%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9162/10000 (91.6%)
#
# One epoch time cost: 45.952 s
#
# -----------------------------------------------
#
# Train Epoch: 36 [0/50000 (0.0%)]	Loss: 0.001315
# Train Epoch: 36 [12800/50000 (25.6%)]	Loss: 0.001547
# Train Epoch: 36 [25600/50000 (51.2%)]	Loss: 0.001293
# Train Epoch: 36 [38400/50000 (76.7%)]	Loss: 0.001549
#
# Training Set: Average loss: 0.0010,Accuracy: 47751/50000 (95.5%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9117/10000 (91.2%)
#
# One epoch time cost: 45.947 s
#
# -----------------------------------------------
#
# Train Epoch: 37 [0/50000 (0.0%)]	Loss: 0.000700
# Train Epoch: 37 [12800/50000 (25.6%)]	Loss: 0.000548
# Train Epoch: 37 [25600/50000 (51.2%)]	Loss: 0.001070
# Train Epoch: 37 [38400/50000 (76.7%)]	Loss: 0.001506
#
# Training Set: Average loss: 0.0009,Accuracy: 47999/50000 (96.0%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9131/10000 (91.3%)
#
# One epoch time cost: 45.970 s
#
# -----------------------------------------------
#
# Train Epoch: 38 [0/50000 (0.0%)]	Loss: 0.000982
# Train Epoch: 38 [12800/50000 (25.6%)]	Loss: 0.001286
# Train Epoch: 38 [25600/50000 (51.2%)]	Loss: 0.001150
# Train Epoch: 38 [38400/50000 (76.7%)]	Loss: 0.000966
#
# Training Set: Average loss: 0.0009,Accuracy: 48131/50000 (96.3%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9136/10000 (91.4%)
#
# One epoch time cost: 46.057 s
#
# -----------------------------------------------
#
# Train Epoch: 39 [0/50000 (0.0%)]	Loss: 0.000696
# Train Epoch: 39 [12800/50000 (25.6%)]	Loss: 0.000624
# Train Epoch: 39 [25600/50000 (51.2%)]	Loss: 0.000535
# Train Epoch: 39 [38400/50000 (76.7%)]	Loss: 0.000906
#
# Training Set: Average loss: 0.0008,Accuracy: 48245/50000 (96.5%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9141/10000 (91.4%)
#
# One epoch time cost: 46.198 s
#
# -----------------------------------------------
#
# Train Epoch: 40 [0/50000 (0.0%)]	Loss: 0.000677
# Train Epoch: 40 [12800/50000 (25.6%)]	Loss: 0.000614
# Train Epoch: 40 [25600/50000 (51.2%)]	Loss: 0.000874
# Train Epoch: 40 [38400/50000 (76.7%)]	Loss: 0.000920
#
# Training Set: Average loss: 0.0008,Accuracy: 48337/50000 (96.7%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9113/10000 (91.1%)
#
# One epoch time cost: 45.913 s
#
# -----------------------------------------------
#
# Train Epoch: 41 [0/50000 (0.0%)]	Loss: 0.000317
# Train Epoch: 41 [12800/50000 (25.6%)]	Loss: 0.000578
# Train Epoch: 41 [25600/50000 (51.2%)]	Loss: 0.000580
# Train Epoch: 41 [38400/50000 (76.7%)]	Loss: 0.000183
#
# Training Set: Average loss: 0.0007,Accuracy: 48375/50000 (96.8%)
#
#
# Test set: Average loss: 0.0030, Accuracy: 9104/10000 (91.0%)
#
# One epoch time cost: 45.935 s
#
# -----------------------------------------------
#
# Train Epoch: 42 [0/50000 (0.0%)]	Loss: 0.000536
# Train Epoch: 42 [12800/50000 (25.6%)]	Loss: 0.000848
# Train Epoch: 42 [25600/50000 (51.2%)]	Loss: 0.001014
# Train Epoch: 42 [38400/50000 (76.7%)]	Loss: 0.000626
#
# Training Set: Average loss: 0.0007,Accuracy: 48412/50000 (96.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9156/10000 (91.6%)
#
# One epoch time cost: 46.039 s
#
# -----------------------------------------------
#
# Train Epoch: 43 [0/50000 (0.0%)]	Loss: 0.000476
# Train Epoch: 43 [12800/50000 (25.6%)]	Loss: 0.000682
# Train Epoch: 43 [25600/50000 (51.2%)]	Loss: 0.000593
# Train Epoch: 43 [38400/50000 (76.7%)]	Loss: 0.000870
#
# Training Set: Average loss: 0.0007,Accuracy: 48509/50000 (97.0%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9206/10000 (92.1%)
#
# One epoch time cost: 49.099 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 44 [0/50000 (0.0%)]	Loss: 0.000526
# Train Epoch: 44 [12800/50000 (25.6%)]	Loss: 0.000289
# Train Epoch: 44 [25600/50000 (51.2%)]	Loss: 0.000634
# Train Epoch: 44 [38400/50000 (76.7%)]	Loss: 0.000230
#
# Training Set: Average loss: 0.0007,Accuracy: 48535/50000 (97.1%)
#
#
# Test set: Average loss: 0.0030, Accuracy: 9131/10000 (91.3%)
#
# One epoch time cost: 46.016 s
#
# -----------------------------------------------
#
# Train Epoch: 45 [0/50000 (0.0%)]	Loss: 0.000466
# Train Epoch: 45 [12800/50000 (25.6%)]	Loss: 0.000488
# Train Epoch: 45 [25600/50000 (51.2%)]	Loss: 0.000501
# Train Epoch: 45 [38400/50000 (76.7%)]	Loss: 0.000512
#
# Training Set: Average loss: 0.0007,Accuracy: 48548/50000 (97.1%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9166/10000 (91.7%)
#
# One epoch time cost: 52.372 s
#
# -----------------------------------------------
#
# Train Epoch: 46 [0/50000 (0.0%)]	Loss: 0.000632
# Train Epoch: 46 [12800/50000 (25.6%)]	Loss: 0.000768
# Train Epoch: 46 [25600/50000 (51.2%)]	Loss: 0.000617
# Train Epoch: 46 [38400/50000 (76.7%)]	Loss: 0.000939
#
# Training Set: Average loss: 0.0006,Accuracy: 48656/50000 (97.3%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9148/10000 (91.5%)
#
# One epoch time cost: 46.004 s
#
# -----------------------------------------------
#
# Train Epoch: 47 [0/50000 (0.0%)]	Loss: 0.000502
# Train Epoch: 47 [12800/50000 (25.6%)]	Loss: 0.000773
# Train Epoch: 47 [25600/50000 (51.2%)]	Loss: 0.000281
# Train Epoch: 47 [38400/50000 (76.7%)]	Loss: 0.000390
#
# Training Set: Average loss: 0.0006,Accuracy: 48686/50000 (97.4%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9175/10000 (91.8%)
#
# One epoch time cost: 45.995 s
#
# -----------------------------------------------
#
# Train Epoch: 48 [0/50000 (0.0%)]	Loss: 0.000387
# Train Epoch: 48 [12800/50000 (25.6%)]	Loss: 0.000622
# Train Epoch: 48 [25600/50000 (51.2%)]	Loss: 0.000413
# Train Epoch: 48 [38400/50000 (76.7%)]	Loss: 0.000335
#
# Training Set: Average loss: 0.0006,Accuracy: 48698/50000 (97.4%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9177/10000 (91.8%)
#
# One epoch time cost: 45.963 s
#
# -----------------------------------------------
#
# Train Epoch: 49 [0/50000 (0.0%)]	Loss: 0.000695
# Train Epoch: 49 [12800/50000 (25.6%)]	Loss: 0.000390
# Train Epoch: 49 [25600/50000 (51.2%)]	Loss: 0.000633
# Train Epoch: 49 [38400/50000 (76.7%)]	Loss: 0.000303
#
# Training Set: Average loss: 0.0006,Accuracy: 48727/50000 (97.5%)
#
#
# Test set: Average loss: 0.0031, Accuracy: 9111/10000 (91.1%)
#
# One epoch time cost: 45.979 s
#
# -----------------------------------------------
#
# Train Epoch: 50 [0/50000 (0.0%)]	Loss: 0.000492
# Train Epoch: 50 [12800/50000 (25.6%)]	Loss: 0.000454
# Train Epoch: 50 [25600/50000 (51.2%)]	Loss: 0.000230
# Train Epoch: 50 [38400/50000 (76.7%)]	Loss: 0.000583
#
# Training Set: Average loss: 0.0004,Accuracy: 49232/50000 (98.5%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9263/10000 (92.6%)
#
# One epoch time cost: 46.124 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 51 [0/50000 (0.0%)]	Loss: 0.000249
# Train Epoch: 51 [12800/50000 (25.6%)]	Loss: 0.000325
# Train Epoch: 51 [25600/50000 (51.2%)]	Loss: 0.000165
# Train Epoch: 51 [38400/50000 (76.7%)]	Loss: 0.000155
#
# Training Set: Average loss: 0.0003,Accuracy: 49430/50000 (98.9%)
#
#
# Test set: Average loss: 0.0025, Accuracy: 9257/10000 (92.6%)
#
# One epoch time cost: 46.019 s
#
# -----------------------------------------------
#
# Train Epoch: 52 [0/50000 (0.0%)]	Loss: 0.000190
# Train Epoch: 52 [12800/50000 (25.6%)]	Loss: 0.000364
# Train Epoch: 52 [25600/50000 (51.2%)]	Loss: 0.000290
# Train Epoch: 52 [38400/50000 (76.7%)]	Loss: 0.000204
#
# Training Set: Average loss: 0.0003,Accuracy: 49521/50000 (99.0%)
#
#
# Test set: Average loss: 0.0025, Accuracy: 9268/10000 (92.7%)
#
# One epoch time cost: 46.055 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 53 [0/50000 (0.0%)]	Loss: 0.000157
# Train Epoch: 53 [12800/50000 (25.6%)]	Loss: 0.000234
# Train Epoch: 53 [25600/50000 (51.2%)]	Loss: 0.000236
# Train Epoch: 53 [38400/50000 (76.7%)]	Loss: 0.000217
#
# Training Set: Average loss: 0.0002,Accuracy: 49587/50000 (99.2%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9250/10000 (92.5%)
#
# One epoch time cost: 46.032 s
#
# -----------------------------------------------
#
# Train Epoch: 54 [0/50000 (0.0%)]	Loss: 0.000170
# Train Epoch: 54 [12800/50000 (25.6%)]	Loss: 0.000435
# Train Epoch: 54 [25600/50000 (51.2%)]	Loss: 0.000316
# Train Epoch: 54 [38400/50000 (76.7%)]	Loss: 0.000110
#
# Training Set: Average loss: 0.0002,Accuracy: 49611/50000 (99.2%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9265/10000 (92.7%)
#
# One epoch time cost: 46.007 s
#
# -----------------------------------------------
#
# Train Epoch: 55 [0/50000 (0.0%)]	Loss: 0.000059
# Train Epoch: 55 [12800/50000 (25.6%)]	Loss: 0.000188
# Train Epoch: 55 [25600/50000 (51.2%)]	Loss: 0.000164
# Train Epoch: 55 [38400/50000 (76.7%)]	Loss: 0.000113
#
# Training Set: Average loss: 0.0002,Accuracy: 49636/50000 (99.3%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9279/10000 (92.8%)
#
# One epoch time cost: 46.039 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 56 [0/50000 (0.0%)]	Loss: 0.000063
# Train Epoch: 56 [12800/50000 (25.6%)]	Loss: 0.000337
# Train Epoch: 56 [25600/50000 (51.2%)]	Loss: 0.000243
# Train Epoch: 56 [38400/50000 (76.7%)]	Loss: 0.000216
#
# Training Set: Average loss: 0.0002,Accuracy: 49644/50000 (99.3%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9273/10000 (92.7%)
#
# One epoch time cost: 46.026 s
#
# -----------------------------------------------
#
# Train Epoch: 57 [0/50000 (0.0%)]	Loss: 0.000278
# Train Epoch: 57 [12800/50000 (25.6%)]	Loss: 0.000150
# Train Epoch: 57 [25600/50000 (51.2%)]	Loss: 0.000193
# Train Epoch: 57 [38400/50000 (76.7%)]	Loss: 0.000138
#
# Training Set: Average loss: 0.0002,Accuracy: 49680/50000 (99.4%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9268/10000 (92.7%)
#
# One epoch time cost: 46.014 s
#
# -----------------------------------------------
#
# Train Epoch: 58 [0/50000 (0.0%)]	Loss: 0.000118
# Train Epoch: 58 [12800/50000 (25.6%)]	Loss: 0.000195
# Train Epoch: 58 [25600/50000 (51.2%)]	Loss: 0.000124
# Train Epoch: 58 [38400/50000 (76.7%)]	Loss: 0.000152
#
# Training Set: Average loss: 0.0002,Accuracy: 49716/50000 (99.4%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9254/10000 (92.5%)
#
# One epoch time cost: 46.057 s
#
# -----------------------------------------------
#
# Train Epoch: 59 [0/50000 (0.0%)]	Loss: 0.000104
# Train Epoch: 59 [12800/50000 (25.6%)]	Loss: 0.000281
# Train Epoch: 59 [25600/50000 (51.2%)]	Loss: 0.000082
# Train Epoch: 59 [38400/50000 (76.7%)]	Loss: 0.000051
#
# Training Set: Average loss: 0.0002,Accuracy: 49735/50000 (99.5%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9276/10000 (92.8%)
#
# One epoch time cost: 46.106 s
#
# -----------------------------------------------
#
# Train Epoch: 60 [0/50000 (0.0%)]	Loss: 0.000256
# Train Epoch: 60 [12800/50000 (25.6%)]	Loss: 0.000101
# Train Epoch: 60 [25600/50000 (51.2%)]	Loss: 0.000077
# Train Epoch: 60 [38400/50000 (76.7%)]	Loss: 0.000452
#
# Training Set: Average loss: 0.0002,Accuracy: 49770/50000 (99.5%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9252/10000 (92.5%)
#
# One epoch time cost: 46.110 s
#
# -----------------------------------------------
#
# Train Epoch: 61 [0/50000 (0.0%)]	Loss: 0.000089
# Train Epoch: 61 [12800/50000 (25.6%)]	Loss: 0.000146
# Train Epoch: 61 [25600/50000 (51.2%)]	Loss: 0.000182
# Train Epoch: 61 [38400/50000 (76.7%)]	Loss: 0.000256
#
# Training Set: Average loss: 0.0002,Accuracy: 49761/50000 (99.5%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9261/10000 (92.6%)
#
# One epoch time cost: 46.139 s
#
# -----------------------------------------------
#
# Train Epoch: 62 [0/50000 (0.0%)]	Loss: 0.000279
# Train Epoch: 62 [12800/50000 (25.6%)]	Loss: 0.000102
# Train Epoch: 62 [25600/50000 (51.2%)]	Loss: 0.000108
# Train Epoch: 62 [38400/50000 (76.7%)]	Loss: 0.000193
#
# Training Set: Average loss: 0.0002,Accuracy: 49751/50000 (99.5%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9268/10000 (92.7%)
#
# One epoch time cost: 46.149 s
#
# -----------------------------------------------
#
# Train Epoch: 63 [0/50000 (0.0%)]	Loss: 0.000161
# Train Epoch: 63 [12800/50000 (25.6%)]	Loss: 0.000140
# Train Epoch: 63 [25600/50000 (51.2%)]	Loss: 0.000186
# Train Epoch: 63 [38400/50000 (76.7%)]	Loss: 0.000089
#
# Training Set: Average loss: 0.0002,Accuracy: 49746/50000 (99.5%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9277/10000 (92.8%)
#
# One epoch time cost: 46.157 s
#
# -----------------------------------------------
#
# Train Epoch: 64 [0/50000 (0.0%)]	Loss: 0.000239
# Train Epoch: 64 [12800/50000 (25.6%)]	Loss: 0.000233
# Train Epoch: 64 [25600/50000 (51.2%)]	Loss: 0.000095
# Train Epoch: 64 [38400/50000 (76.7%)]	Loss: 0.000144
#
# Training Set: Average loss: 0.0001,Accuracy: 49775/50000 (99.6%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9282/10000 (92.8%)
#
# One epoch time cost: 46.161 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 65 [0/50000 (0.0%)]	Loss: 0.000328
# Train Epoch: 65 [12800/50000 (25.6%)]	Loss: 0.000067
# Train Epoch: 65 [25600/50000 (51.2%)]	Loss: 0.000086
# Train Epoch: 65 [38400/50000 (76.7%)]	Loss: 0.000194
#
# Training Set: Average loss: 0.0001,Accuracy: 49797/50000 (99.6%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9276/10000 (92.8%)
#
# One epoch time cost: 46.199 s
#
# -----------------------------------------------
#
# Train Epoch: 66 [0/50000 (0.0%)]	Loss: 0.000110
# Train Epoch: 66 [12800/50000 (25.6%)]	Loss: 0.000101
# Train Epoch: 66 [25600/50000 (51.2%)]	Loss: 0.000311
# Train Epoch: 66 [38400/50000 (76.7%)]	Loss: 0.000034
#
# Training Set: Average loss: 0.0001,Accuracy: 49778/50000 (99.6%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9297/10000 (93.0%)
#
# One epoch time cost: 46.220 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 67 [0/50000 (0.0%)]	Loss: 0.000145
# Train Epoch: 67 [12800/50000 (25.6%)]	Loss: 0.000167
# Train Epoch: 67 [25600/50000 (51.2%)]	Loss: 0.000116
# Train Epoch: 67 [38400/50000 (76.7%)]	Loss: 0.000047
#
# Training Set: Average loss: 0.0001,Accuracy: 49788/50000 (99.6%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9285/10000 (92.8%)
#
# One epoch time cost: 46.238 s
#
# -----------------------------------------------
#
# Train Epoch: 68 [0/50000 (0.0%)]	Loss: 0.000165
# Train Epoch: 68 [12800/50000 (25.6%)]	Loss: 0.000397
# Train Epoch: 68 [25600/50000 (51.2%)]	Loss: 0.000365
# Train Epoch: 68 [38400/50000 (76.7%)]	Loss: 0.000135
#
# Training Set: Average loss: 0.0001,Accuracy: 49816/50000 (99.6%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9275/10000 (92.8%)
#
# One epoch time cost: 46.291 s
#
# -----------------------------------------------
#
# Train Epoch: 69 [0/50000 (0.0%)]	Loss: 0.000087
# Train Epoch: 69 [12800/50000 (25.6%)]	Loss: 0.000098
# Train Epoch: 69 [25600/50000 (51.2%)]	Loss: 0.000051
# Train Epoch: 69 [38400/50000 (76.7%)]	Loss: 0.000059
#
# Training Set: Average loss: 0.0001,Accuracy: 49816/50000 (99.6%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9281/10000 (92.8%)
#
# One epoch time cost: 46.282 s
#
# -----------------------------------------------
#
# Train Epoch: 70 [0/50000 (0.0%)]	Loss: 0.000253
# Train Epoch: 70 [12800/50000 (25.6%)]	Loss: 0.000162
# Train Epoch: 70 [25600/50000 (51.2%)]	Loss: 0.000059
# Train Epoch: 70 [38400/50000 (76.7%)]	Loss: 0.000216
#
# Training Set: Average loss: 0.0001,Accuracy: 49833/50000 (99.7%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9289/10000 (92.9%)
#
# One epoch time cost: 46.298 s
#
# -----------------------------------------------
#
# Train Epoch: 71 [0/50000 (0.0%)]	Loss: 0.000137
# Train Epoch: 71 [12800/50000 (25.6%)]	Loss: 0.000061
# Train Epoch: 71 [25600/50000 (51.2%)]	Loss: 0.000038
# Train Epoch: 71 [38400/50000 (76.7%)]	Loss: 0.000046
#
# Training Set: Average loss: 0.0001,Accuracy: 49828/50000 (99.7%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9286/10000 (92.9%)
#
# One epoch time cost: 46.296 s
#
# -----------------------------------------------
#
# Train Epoch: 72 [0/50000 (0.0%)]	Loss: 0.000094
# Train Epoch: 72 [12800/50000 (25.6%)]	Loss: 0.000041
# Train Epoch: 72 [25600/50000 (51.2%)]	Loss: 0.000082
# Train Epoch: 72 [38400/50000 (76.7%)]	Loss: 0.000047
#
# Training Set: Average loss: 0.0001,Accuracy: 49842/50000 (99.7%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9271/10000 (92.7%)
#
# One epoch time cost: 46.238 s
#
# -----------------------------------------------
#
# Train Epoch: 73 [0/50000 (0.0%)]	Loss: 0.000051
# Train Epoch: 73 [12800/50000 (25.6%)]	Loss: 0.000070
# Train Epoch: 73 [25600/50000 (51.2%)]	Loss: 0.000081
# Train Epoch: 73 [38400/50000 (76.7%)]	Loss: 0.000217
#
# Training Set: Average loss: 0.0001,Accuracy: 49856/50000 (99.7%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9286/10000 (92.9%)
#
# One epoch time cost: 46.294 s
#
# -----------------------------------------------
#
# Train Epoch: 74 [0/50000 (0.0%)]	Loss: 0.000185
# Train Epoch: 74 [12800/50000 (25.6%)]	Loss: 0.000079
# Train Epoch: 74 [25600/50000 (51.2%)]	Loss: 0.000072
# Train Epoch: 74 [38400/50000 (76.7%)]	Loss: 0.000070
#
# Training Set: Average loss: 0.0001,Accuracy: 49846/50000 (99.7%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9272/10000 (92.7%)
#
# One epoch time cost: 46.323 s
#
# -----------------------------------------------
#
# Train Epoch: 75 [0/50000 (0.0%)]	Loss: 0.000210
# Train Epoch: 75 [12800/50000 (25.6%)]	Loss: 0.000130
# Train Epoch: 75 [25600/50000 (51.2%)]	Loss: 0.000089
# Train Epoch: 75 [38400/50000 (76.7%)]	Loss: 0.000121
#
# Training Set: Average loss: 0.0001,Accuracy: 49858/50000 (99.7%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9288/10000 (92.9%)
#
# One epoch time cost: 49.999 s
#
# -----------------------------------------------
#
# Train Epoch: 76 [0/50000 (0.0%)]	Loss: 0.000075
# Train Epoch: 76 [12800/50000 (25.6%)]	Loss: 0.000088
# Train Epoch: 76 [25600/50000 (51.2%)]	Loss: 0.000076
# Train Epoch: 76 [38400/50000 (76.7%)]	Loss: 0.000075
#
# Training Set: Average loss: 0.0001,Accuracy: 49869/50000 (99.7%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9283/10000 (92.8%)
#
# One epoch time cost: 46.072 s
#
# -----------------------------------------------
#
# Train Epoch: 77 [0/50000 (0.0%)]	Loss: 0.000185
# Train Epoch: 77 [12800/50000 (25.6%)]	Loss: 0.000038
# Train Epoch: 77 [25600/50000 (51.2%)]	Loss: 0.000192
# Train Epoch: 77 [38400/50000 (76.7%)]	Loss: 0.000105
#
# Training Set: Average loss: 0.0001,Accuracy: 49880/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9278/10000 (92.8%)
#
# One epoch time cost: 45.716 s
#
# -----------------------------------------------
#
# Train Epoch: 78 [0/50000 (0.0%)]	Loss: 0.000132
# Train Epoch: 78 [12800/50000 (25.6%)]	Loss: 0.000332
# Train Epoch: 78 [25600/50000 (51.2%)]	Loss: 0.000026
# Train Epoch: 78 [38400/50000 (76.7%)]	Loss: 0.000079
#
# Training Set: Average loss: 0.0001,Accuracy: 49860/50000 (99.7%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9286/10000 (92.9%)
#
# One epoch time cost: 46.171 s
#
# -----------------------------------------------
#
# Train Epoch: 79 [0/50000 (0.0%)]	Loss: 0.000061
# Train Epoch: 79 [12800/50000 (25.6%)]	Loss: 0.000044
# Train Epoch: 79 [25600/50000 (51.2%)]	Loss: 0.000049
# Train Epoch: 79 [38400/50000 (76.7%)]	Loss: 0.000413
#
# Training Set: Average loss: 0.0001,Accuracy: 49877/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9280/10000 (92.8%)
#
# One epoch time cost: 46.046 s
#
# -----------------------------------------------
#
# Train Epoch: 80 [0/50000 (0.0%)]	Loss: 0.000073
# Train Epoch: 80 [12800/50000 (25.6%)]	Loss: 0.000067
# Train Epoch: 80 [25600/50000 (51.2%)]	Loss: 0.000091
# Train Epoch: 80 [38400/50000 (76.7%)]	Loss: 0.000237
#
# Training Set: Average loss: 0.0001,Accuracy: 49876/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9275/10000 (92.8%)
#
# One epoch time cost: 49.071 s
#
# -----------------------------------------------
#
# Train Epoch: 81 [0/50000 (0.0%)]	Loss: 0.000089
# Train Epoch: 81 [12800/50000 (25.6%)]	Loss: 0.000048
# Train Epoch: 81 [25600/50000 (51.2%)]	Loss: 0.000074
# Train Epoch: 81 [38400/50000 (76.7%)]	Loss: 0.000036
#
# Training Set: Average loss: 0.0001,Accuracy: 49887/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9287/10000 (92.9%)
#
# One epoch time cost: 46.113 s
#
# -----------------------------------------------
#
# Train Epoch: 82 [0/50000 (0.0%)]	Loss: 0.000070
# Train Epoch: 82 [12800/50000 (25.6%)]	Loss: 0.000175
# Train Epoch: 82 [25600/50000 (51.2%)]	Loss: 0.000040
# Train Epoch: 82 [38400/50000 (76.7%)]	Loss: 0.000081
#
# Training Set: Average loss: 0.0001,Accuracy: 49884/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9296/10000 (93.0%)
#
# One epoch time cost: 46.043 s
#
# -----------------------------------------------
#
# Train Epoch: 83 [0/50000 (0.0%)]	Loss: 0.000049
# Train Epoch: 83 [12800/50000 (25.6%)]	Loss: 0.000041
# Train Epoch: 83 [25600/50000 (51.2%)]	Loss: 0.000026
# Train Epoch: 83 [38400/50000 (76.7%)]	Loss: 0.000056
#
# Training Set: Average loss: 0.0001,Accuracy: 49895/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9296/10000 (93.0%)
#
# One epoch time cost: 45.924 s
#
# -----------------------------------------------
#
# Train Epoch: 84 [0/50000 (0.0%)]	Loss: 0.000088
# Train Epoch: 84 [12800/50000 (25.6%)]	Loss: 0.000263
# Train Epoch: 84 [25600/50000 (51.2%)]	Loss: 0.000099
# Train Epoch: 84 [38400/50000 (76.7%)]	Loss: 0.000034
#
# Training Set: Average loss: 0.0001,Accuracy: 49902/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9300/10000 (93.0%)
#
# One epoch time cost: 45.823 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 85 [0/50000 (0.0%)]	Loss: 0.000220
# Train Epoch: 85 [12800/50000 (25.6%)]	Loss: 0.000024
# Train Epoch: 85 [25600/50000 (51.2%)]	Loss: 0.000091
# Train Epoch: 85 [38400/50000 (76.7%)]	Loss: 0.000406
#
# Training Set: Average loss: 0.0001,Accuracy: 49887/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9289/10000 (92.9%)
#
# One epoch time cost: 45.850 s
#
# -----------------------------------------------
#
# Train Epoch: 86 [0/50000 (0.0%)]	Loss: 0.000053
# Train Epoch: 86 [12800/50000 (25.6%)]	Loss: 0.000043
# Train Epoch: 86 [25600/50000 (51.2%)]	Loss: 0.000042
# Train Epoch: 86 [38400/50000 (76.7%)]	Loss: 0.000128
#
# Training Set: Average loss: 0.0001,Accuracy: 49903/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9288/10000 (92.9%)
#
# One epoch time cost: 45.887 s
#
# -----------------------------------------------
#
# Train Epoch: 87 [0/50000 (0.0%)]	Loss: 0.000146
# Train Epoch: 87 [12800/50000 (25.6%)]	Loss: 0.000050
# Train Epoch: 87 [25600/50000 (51.2%)]	Loss: 0.000123
# Train Epoch: 87 [38400/50000 (76.7%)]	Loss: 0.000087
#
# Training Set: Average loss: 0.0001,Accuracy: 49896/50000 (99.8%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9300/10000 (93.0%)
#
# One epoch time cost: 45.783 s
#
# -----------------------------------------------
#
# Train Epoch: 88 [0/50000 (0.0%)]	Loss: 0.000052
# Train Epoch: 88 [12800/50000 (25.6%)]	Loss: 0.000069
# Train Epoch: 88 [25600/50000 (51.2%)]	Loss: 0.000043
# Train Epoch: 88 [38400/50000 (76.7%)]	Loss: 0.000121
#
# Training Set: Average loss: 0.0001,Accuracy: 49889/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9296/10000 (93.0%)
#
# One epoch time cost: 45.796 s
#
# -----------------------------------------------
#
# Train Epoch: 89 [0/50000 (0.0%)]	Loss: 0.000093
# Train Epoch: 89 [12800/50000 (25.6%)]	Loss: 0.000040
# Train Epoch: 89 [25600/50000 (51.2%)]	Loss: 0.000033
# Train Epoch: 89 [38400/50000 (76.7%)]	Loss: 0.000051
#
# Training Set: Average loss: 0.0001,Accuracy: 49907/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9316/10000 (93.2%)
#
# One epoch time cost: 45.786 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 90 [0/50000 (0.0%)]	Loss: 0.000038
# Train Epoch: 90 [12800/50000 (25.6%)]	Loss: 0.000090
# Train Epoch: 90 [25600/50000 (51.2%)]	Loss: 0.000188
# Train Epoch: 90 [38400/50000 (76.7%)]	Loss: 0.000043
#
# Training Set: Average loss: 0.0001,Accuracy: 49920/50000 (99.8%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9323/10000 (93.2%)
#
# One epoch time cost: 46.109 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 91 [0/50000 (0.0%)]	Loss: 0.000113
# Train Epoch: 91 [12800/50000 (25.6%)]	Loss: 0.000054
# Train Epoch: 91 [25600/50000 (51.2%)]	Loss: 0.000078
# Train Epoch: 91 [38400/50000 (76.7%)]	Loss: 0.000114
#
# Training Set: Average loss: 0.0001,Accuracy: 49920/50000 (99.8%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9306/10000 (93.1%)
#
# One epoch time cost: 45.903 s
#
# -----------------------------------------------
#
# Train Epoch: 92 [0/50000 (0.0%)]	Loss: 0.000109
# Train Epoch: 92 [12800/50000 (25.6%)]	Loss: 0.000048
# Train Epoch: 92 [25600/50000 (51.2%)]	Loss: 0.000022
# Train Epoch: 92 [38400/50000 (76.7%)]	Loss: 0.000053
#
# Training Set: Average loss: 0.0001,Accuracy: 49908/50000 (99.8%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9286/10000 (92.9%)
#
# One epoch time cost: 45.676 s
#
# -----------------------------------------------
#
# Train Epoch: 93 [0/50000 (0.0%)]	Loss: 0.000379
# Train Epoch: 93 [12800/50000 (25.6%)]	Loss: 0.000055
# Train Epoch: 93 [25600/50000 (51.2%)]	Loss: 0.000115
# Train Epoch: 93 [38400/50000 (76.7%)]	Loss: 0.000044
#
# Training Set: Average loss: 0.0001,Accuracy: 49915/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9307/10000 (93.1%)
#
# One epoch time cost: 45.960 s
#
# -----------------------------------------------
#
# Train Epoch: 94 [0/50000 (0.0%)]	Loss: 0.000064
# Train Epoch: 94 [12800/50000 (25.6%)]	Loss: 0.000016
# Train Epoch: 94 [25600/50000 (51.2%)]	Loss: 0.000071
# Train Epoch: 94 [38400/50000 (76.7%)]	Loss: 0.000057
#
# Training Set: Average loss: 0.0001,Accuracy: 49915/50000 (99.8%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9290/10000 (92.9%)
#
# One epoch time cost: 46.179 s
#
# -----------------------------------------------
#
# Train Epoch: 95 [0/50000 (0.0%)]	Loss: 0.000053
# Train Epoch: 95 [12800/50000 (25.6%)]	Loss: 0.000065
# Train Epoch: 95 [25600/50000 (51.2%)]	Loss: 0.000156
# Train Epoch: 95 [38400/50000 (76.7%)]	Loss: 0.000060
#
# Training Set: Average loss: 0.0001,Accuracy: 49915/50000 (99.8%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9298/10000 (93.0%)
#
# One epoch time cost: 46.064 s
#
# -----------------------------------------------
#
# Train Epoch: 96 [0/50000 (0.0%)]	Loss: 0.000029
# Train Epoch: 96 [12800/50000 (25.6%)]	Loss: 0.000038
# Train Epoch: 96 [25600/50000 (51.2%)]	Loss: 0.000035
# Train Epoch: 96 [38400/50000 (76.7%)]	Loss: 0.000123
#
# Training Set: Average loss: 0.0001,Accuracy: 49916/50000 (99.8%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9293/10000 (92.9%)
#
# One epoch time cost: 46.019 s
#
# -----------------------------------------------
#
# Train Epoch: 97 [0/50000 (0.0%)]	Loss: 0.000045
# Train Epoch: 97 [12800/50000 (25.6%)]	Loss: 0.000038
# Train Epoch: 97 [25600/50000 (51.2%)]	Loss: 0.000125
# Train Epoch: 97 [38400/50000 (76.7%)]	Loss: 0.000108
#
# Training Set: Average loss: 0.0001,Accuracy: 49912/50000 (99.8%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9306/10000 (93.1%)
#
# One epoch time cost: 46.049 s
#
# -----------------------------------------------
#
# Train Epoch: 98 [0/50000 (0.0%)]	Loss: 0.000035
# Train Epoch: 98 [12800/50000 (25.6%)]	Loss: 0.000077
# Train Epoch: 98 [25600/50000 (51.2%)]	Loss: 0.000086
# Train Epoch: 98 [38400/50000 (76.7%)]	Loss: 0.000051
#
# Training Set: Average loss: 0.0001,Accuracy: 49933/50000 (99.9%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9314/10000 (93.1%)
#
# One epoch time cost: 45.942 s
#
# -----------------------------------------------
#
# Train Epoch: 99 [0/50000 (0.0%)]	Loss: 0.000080
# Train Epoch: 99 [12800/50000 (25.6%)]	Loss: 0.000142
# Train Epoch: 99 [25600/50000 (51.2%)]	Loss: 0.000131
# Train Epoch: 99 [38400/50000 (76.7%)]	Loss: 0.000044
#
# Training Set: Average loss: 0.0001,Accuracy: 49926/50000 (99.9%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9295/10000 (92.9%)
#
# One epoch time cost: 45.911 s
#
# -----------------------------------------------
#
# Best accuracy: tensor(0.9323)
