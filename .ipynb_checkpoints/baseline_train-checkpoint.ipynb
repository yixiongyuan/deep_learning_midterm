# %%
# this file is for  base line model training

# %%
#import useful package
from __future__ import print_function
import os
import argparse
import shutil

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


import torchvision
from torchvision import datasets, transforms

import models
from torchinfo import summary
from collections import OrderedDict
from matplotlib import pyplot as plt

# %%
# set up device 
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
# Out:
# cuda

# %%
# downlaoding data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
train_loader = torch.utils.data.DataLoader(
    trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
test_loader = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# load baseline mode
print('==> Building model..')

model = models.resnet()
params = sum(p.numel() for p in model.parameters())
print(params)
# print the overall architecture
summary(model, input_size=(1,3, 32, 32))
# Out:
# ==> Building model..
# 11105866
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# resnet                                   [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 64, 32, 32]           1,728
# ├─Sequential: 1-2                        [1, 64, 32, 32]           --
# │    └─FusionBlock: 2-1                  [1, 64, 32, 32]           --
# │    │    └─Sequential: 3-1              [1, 64, 32, 32]           4,928
# │    │    └─BatchNorm2d: 3-2             [1, 64, 32, 32]           128
# │    │    └─ReLU: 3-3                    [1, 64, 32, 32]           --
# │    │    └─Sequential: 3-4              [1, 64, 32, 32]           4,928
# │    │    └─BatchNorm2d: 3-5             [1, 64, 32, 32]           128
# │    │    └─ReLU: 3-6                    [1, 64, 32, 32]           --
# │    └─FusionBlock: 2-2                  [1, 64, 32, 32]           --
# │    │    └─Sequential: 3-7              [1, 64, 32, 32]           4,928
# │    │    └─BatchNorm2d: 3-8             [1, 64, 32, 32]           128
# │    │    └─ReLU: 3-9                    [1, 64, 32, 32]           --
# │    │    └─Sequential: 3-10             [1, 64, 32, 32]           4,928
# │    │    └─BatchNorm2d: 3-11            [1, 64, 32, 32]           128
# │    │    └─Sequential: 3-12             [1, 64, 32, 32]           102,528
# │    │    └─ReLU: 3-13                   [1, 64, 32, 32]           --
# ├─Sequential: 1-3                        [1, 128, 16, 16]          --
# │    └─FusionBlock: 2-3                  [1, 128, 16, 16]          --
# │    │    └─Sequential: 3-14             [1, 128, 16, 16]          9,216
# │    │    └─BatchNorm2d: 3-15            [1, 128, 16, 16]          256
# │    │    └─ReLU: 3-16                   [1, 128, 16, 16]          --
# │    │    └─Sequential: 3-17             [1, 128, 16, 16]          18,048
# │    │    └─BatchNorm2d: 3-18            [1, 128, 16, 16]          256
# │    │    └─Sequential: 3-19             [1, 128, 16, 16]          8,192
# │    │    └─ReLU: 3-20                   [1, 128, 16, 16]          --
# │    └─FusionBlock: 2-4                  [1, 128, 16, 16]          --
# │    │    └─Sequential: 3-21             [1, 128, 16, 16]          18,048
# │    │    └─BatchNorm2d: 3-22            [1, 128, 16, 16]          256
# │    │    └─ReLU: 3-23                   [1, 128, 16, 16]          --
# │    │    └─Sequential: 3-24             [1, 128, 16, 16]          18,048
# │    │    └─BatchNorm2d: 3-25            [1, 128, 16, 16]          256
# │    │    └─Sequential: 3-26             [1, 128, 16, 16]          409,856
# │    │    └─ReLU: 3-27                   [1, 128, 16, 16]          --
# ├─Sequential: 1-4                        [1, 256, 8, 8]            --
# │    └─BasicBlock: 2-5                   [1, 256, 8, 8]            --
# │    │    └─BatchNorm2d: 3-28            [1, 128, 16, 16]          256
# │    │    └─channel_selection: 3-29      [1, 128, 16, 16]          128
# │    │    └─ReLU: 3-30                   [1, 128, 16, 16]          --
# │    │    └─Conv2d: 3-31                 [1, 256, 8, 8]            294,912
# │    │    └─BatchNorm2d: 3-32            [1, 256, 8, 8]            512
# │    │    └─ReLU: 3-33                   [1, 256, 8, 8]            --
# │    │    └─Conv2d: 3-34                 [1, 256, 8, 8]            589,824
# │    │    └─Sequential: 3-35             [1, 256, 8, 8]            32,768
# │    └─BasicBlock: 2-6                   [1, 256, 8, 8]            --
# │    │    └─BatchNorm2d: 3-36            [1, 256, 8, 8]            512
# │    │    └─channel_selection: 3-37      [1, 256, 8, 8]            256
# │    │    └─ReLU: 3-38                   [1, 256, 8, 8]            --
# │    │    └─Conv2d: 3-39                 [1, 256, 8, 8]            589,824
# │    │    └─BatchNorm2d: 3-40            [1, 256, 8, 8]            512
# │    │    └─ReLU: 3-41                   [1, 256, 8, 8]            --
# │    │    └─Conv2d: 3-42                 [1, 256, 8, 8]            589,824
# ├─Sequential: 1-5                        [1, 512, 4, 4]            --
# │    └─BasicBlock: 2-7                   [1, 512, 4, 4]            --
# │    │    └─BatchNorm2d: 3-43            [1, 256, 8, 8]            512
# │    │    └─channel_selection: 3-44      [1, 256, 8, 8]            256
# │    │    └─ReLU: 3-45                   [1, 256, 8, 8]            --
# │    │    └─Conv2d: 3-46                 [1, 512, 4, 4]            1,179,648
# │    │    └─BatchNorm2d: 3-47            [1, 512, 4, 4]            1,024
# │    │    └─ReLU: 3-48                   [1, 512, 4, 4]            --
# │    │    └─Conv2d: 3-49                 [1, 512, 4, 4]            2,359,296
# │    │    └─Sequential: 3-50             [1, 512, 4, 4]            131,072
# │    └─BasicBlock: 2-8                   [1, 512, 4, 4]            --
# │    │    └─BatchNorm2d: 3-51            [1, 512, 4, 4]            1,024
# │    │    └─channel_selection: 3-52      [1, 512, 4, 4]            512
# │    │    └─ReLU: 3-53                   [1, 512, 4, 4]            --
# │    │    └─Conv2d: 3-54                 [1, 512, 4, 4]            2,359,296
# │    │    └─BatchNorm2d: 3-55            [1, 512, 4, 4]            1,024
# │    │    └─ReLU: 3-56                   [1, 512, 4, 4]            --
# │    │    └─Conv2d: 3-57                 [1, 512, 4, 4]            2,359,296
# ├─BatchNorm2d: 1-6                       [1, 512, 4, 4]            1,024
# ├─channel_selection: 1-7                 [1, 512, 4, 4]            512
# ├─ReLU: 1-8                              [1, 512, 4, 4]            --
# ├─AvgPool2d: 1-9                         [1, 512, 1, 1]            --
# ├─Linear: 1-10                           [1, 10]                   5,130
# ==========================================================================================
# Total params: 11,105,866
# Trainable params: 11,105,866
# Non-trainable params: 0
# Total mult-adds (M): 517.65
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 17.50
# Params size (MB): 44.42
# Estimated Total Size (MB): 61.93
# ==========================================================================================

# %%
# loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1,momentum=0.9, weight_decay=5e-4)

# %%
# additional subgradient descent on the sparsity-induced penalty term

# trade-off factors 
s  = 0.00001

# add new item on grad computation
def updateBN():
    for name,m in model.named_modules():
        if isinstance(m, nn.BatchNorm2d) and 'fusion' not in name:
            m.weight.grad.data.add_(s*torch.sign(m.weight.data))  # L1 regularization

#training function
def train(epoch,train_loss_list,train_acc_list):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        
        data, target = data.to(device), target.to(device)
        
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        train_loss +=loss.item()
        
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()
        
        loss.backward()
        
        # calculate the gradient for BN scaling factors
        updateBN()
        
        optimizer.step()
        
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()/len(data)))
                  
    train_loss /= len(train_loader.dataset)
    train_loss_list.append(train_loss)
    train_acc = correct / len(train_loader.dataset)
    train_acc_list.append(train_acc)
    
    print('\nTraining Set: Average loss: {:.4f},Accuracy: {}/{} ({:.1f}%)\n'.format(
            train_loss, correct, len(train_loader.dataset),100.*train_acc))

# test function
def test(test_loss_list,test_acc_list):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:

            data, target = data.to(device), target.to(device)
            output = model(data)

            loss = criterion(output, target)
            test_loss += loss.item() # sum up batch loss

            pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.data.view_as(pred)).cpu().sum()

        test_loss /= len(test_loader.dataset)
        test_loss_list.append(test_loss)
        test_acc = correct / float(len(test_loader.dataset))
        test_acc_list.append(test_acc)
        
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset), 100. * test_acc))
        
        return test_acc

def save_checkpoint(state, is_best, filepath):
    torch.save(state, os.path.join(filepath, 'baseline.pth.tar'))
    if is_best:
        print('\n!!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!! \n')
        shutil.copyfile(os.path.join(filepath, 'baseline.pth.tar'), os.path.join(filepath, 'baseline_model_best.pth.tar'))

# %%
best_prec1 = 0.

import time

if not os.path.isdir('checkpoint'):
    os.mkdir('checkpoint')

train_loss = []
train_acc = []
test_loss = []
test_acc = []

# training 
for epoch in range(0, 150):
    if epoch in [30, 60]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1
        
    start_time = time.time()
    
    train(epoch,train_loss,train_acc)
    prec1 = test(test_loss,test_acc)
    
    end_time = time.time()
    
    interval = end_time - start_time
    print('One epoch time cost: {:.3f} s \n'.format(interval))
   
    
    is_best = prec1 > best_prec1
    best_prec1 = max(prec1, best_prec1)
    
    save_checkpoint({
        'epoch': epoch + 1,
        'state_dict': model.state_dict(),
        'best_prec1': best_prec1,
        'optimizer': optimizer.state_dict(),
    }, is_best, filepath='./checkpoint/baseline')
    
    print('----------------------------------------------- \n')

    
print("Best accuracy: "+str(best_prec1))

# write loss data to txt file
savepath = os.path.join('./checkpoint/baseline', "baseline_train_loss.txt")
with open(savepath, "w") as fp:
    for data in train_loss:
        fp.write(str(data)+"\n")
    
savepath = os.path.join('./checkpoint/baseline', "baseline_train_acc.txt")
with open(savepath, "w") as fp:
       for data in train_acc:
        fp.write(str(data)+"\n")
    
savepath = os.path.join('./checkpoint/baseline', "baseline_test_loss.txt")
with open(savepath, "w") as fp:
    for data in test_loss:
        fp.write(str(data)+"\n")
    
savepath = os.path.join('./checkpoint/baseline', "baseline_test_acc.txt")
with open(savepath, "w") as fp:
    for data in test_acc:
        fp.write(str(data)+"\n")
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 0.018080
# Train Epoch: 0 [12800/50000 (25.6%)]	Loss: 0.012758
# Train Epoch: 0 [25600/50000 (51.2%)]	Loss: 0.011434
# Train Epoch: 0 [38400/50000 (76.7%)]	Loss: 0.010146
#
# Training Set: Average loss: 0.0122,Accuracy: 20902/50000 (41.8%)
#
#
# Test set: Average loss: 0.0131, Accuracy: 5231/10000 (52.3%)
#
# One epoch time cost: 48.898 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 0.010112
# Train Epoch: 1 [12800/50000 (25.6%)]	Loss: 0.009741
# Train Epoch: 1 [25600/50000 (51.2%)]	Loss: 0.008112
# Train Epoch: 1 [38400/50000 (76.7%)]	Loss: 0.008449
#
# Training Set: Average loss: 0.0084,Accuracy: 30685/50000 (61.4%)
#
#
# Test set: Average loss: 0.0098, Accuracy: 6530/10000 (65.3%)
#
# One epoch time cost: 49.766 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.008077
# Train Epoch: 2 [12800/50000 (25.6%)]	Loss: 0.006255
# Train Epoch: 2 [25600/50000 (51.2%)]	Loss: 0.005299
# Train Epoch: 2 [38400/50000 (76.7%)]	Loss: 0.006139
#
# Training Set: Average loss: 0.0067,Accuracy: 34899/50000 (69.8%)
#
#
# Test set: Average loss: 0.0106, Accuracy: 6411/10000 (64.1%)
#
# One epoch time cost: 50.850 s
#
# -----------------------------------------------
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.004582
# Train Epoch: 3 [12800/50000 (25.6%)]	Loss: 0.005687
# Train Epoch: 3 [25600/50000 (51.2%)]	Loss: 0.005294
# Train Epoch: 3 [38400/50000 (76.7%)]	Loss: 0.007723
#
# Training Set: Average loss: 0.0057,Accuracy: 37438/50000 (74.9%)
#
#
# Test set: Average loss: 0.0069, Accuracy: 7616/10000 (76.2%)
#
# One epoch time cost: 51.220 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.004958
# Train Epoch: 4 [12800/50000 (25.6%)]	Loss: 0.004778
# Train Epoch: 4 [25600/50000 (51.2%)]	Loss: 0.004716
# Train Epoch: 4 [38400/50000 (76.7%)]	Loss: 0.006057
#
# Training Set: Average loss: 0.0050,Accuracy: 38905/50000 (77.8%)
#
#
# Test set: Average loss: 0.0074, Accuracy: 7464/10000 (74.6%)
#
# One epoch time cost: 51.481 s
#
# -----------------------------------------------
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.005132
# Train Epoch: 5 [12800/50000 (25.6%)]	Loss: 0.004972
# Train Epoch: 5 [25600/50000 (51.2%)]	Loss: 0.003420
# Train Epoch: 5 [38400/50000 (76.7%)]	Loss: 0.004395
#
# Training Set: Average loss: 0.0047,Accuracy: 39701/50000 (79.4%)
#
#
# Test set: Average loss: 0.0075, Accuracy: 7546/10000 (75.5%)
#
# One epoch time cost: 51.347 s
#
# -----------------------------------------------
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.005477
# Train Epoch: 6 [12800/50000 (25.6%)]	Loss: 0.004300
# Train Epoch: 6 [25600/50000 (51.2%)]	Loss: 0.003976
# Train Epoch: 6 [38400/50000 (76.7%)]	Loss: 0.005533
#
# Training Set: Average loss: 0.0044,Accuracy: 40238/50000 (80.5%)
#
#
# Test set: Average loss: 0.0076, Accuracy: 7433/10000 (74.3%)
#
# One epoch time cost: 51.296 s
#
# -----------------------------------------------
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.003652
# Train Epoch: 7 [12800/50000 (25.6%)]	Loss: 0.004501
# Train Epoch: 7 [25600/50000 (51.2%)]	Loss: 0.004464
# Train Epoch: 7 [38400/50000 (76.7%)]	Loss: 0.004356
#
# Training Set: Average loss: 0.0042,Accuracy: 40790/50000 (81.6%)
#
#
# Test set: Average loss: 0.0067, Accuracy: 7742/10000 (77.4%)
#
# One epoch time cost: 51.296 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.003895
# Train Epoch: 8 [12800/50000 (25.6%)]	Loss: 0.003862
# Train Epoch: 8 [25600/50000 (51.2%)]	Loss: 0.003595
# Train Epoch: 8 [38400/50000 (76.7%)]	Loss: 0.004086
#
# Training Set: Average loss: 0.0040,Accuracy: 41148/50000 (82.3%)
#
#
# Test set: Average loss: 0.0064, Accuracy: 7862/10000 (78.6%)
#
# One epoch time cost: 51.301 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.003467
# Train Epoch: 9 [12800/50000 (25.6%)]	Loss: 0.003435
# Train Epoch: 9 [25600/50000 (51.2%)]	Loss: 0.003963
# Train Epoch: 9 [38400/50000 (76.7%)]	Loss: 0.002819
#
# Training Set: Average loss: 0.0039,Accuracy: 41609/50000 (83.2%)
#
#
# Test set: Average loss: 0.0056, Accuracy: 8042/10000 (80.4%)
#
# One epoch time cost: 51.277 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.004239
# Train Epoch: 10 [12800/50000 (25.6%)]	Loss: 0.004050
# Train Epoch: 10 [25600/50000 (51.2%)]	Loss: 0.003982
# Train Epoch: 10 [38400/50000 (76.7%)]	Loss: 0.004213
#
# Training Set: Average loss: 0.0038,Accuracy: 41610/50000 (83.2%)
#
#
# Test set: Average loss: 0.0055, Accuracy: 8134/10000 (81.3%)
#
# One epoch time cost: 51.271 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.004504
# Train Epoch: 11 [12800/50000 (25.6%)]	Loss: 0.003417
# Train Epoch: 11 [25600/50000 (51.2%)]	Loss: 0.003312
# Train Epoch: 11 [38400/50000 (76.7%)]	Loss: 0.004414
#
# Training Set: Average loss: 0.0037,Accuracy: 41981/50000 (84.0%)
#
#
# Test set: Average loss: 0.0065, Accuracy: 7828/10000 (78.3%)
#
# One epoch time cost: 51.305 s
#
# -----------------------------------------------
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.003625
# Train Epoch: 12 [12800/50000 (25.6%)]	Loss: 0.003011
# Train Epoch: 12 [25600/50000 (51.2%)]	Loss: 0.003318
# Train Epoch: 12 [38400/50000 (76.7%)]	Loss: 0.004697
#
# Training Set: Average loss: 0.0036,Accuracy: 42074/50000 (84.1%)
#
#
# Test set: Average loss: 0.0066, Accuracy: 7892/10000 (78.9%)
#
# One epoch time cost: 51.319 s
#
# -----------------------------------------------
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.003330
# Train Epoch: 13 [12800/50000 (25.6%)]	Loss: 0.002834
# Train Epoch: 13 [25600/50000 (51.2%)]	Loss: 0.003731
# Train Epoch: 13 [38400/50000 (76.7%)]	Loss: 0.003250
#
# Training Set: Average loss: 0.0035,Accuracy: 42305/50000 (84.6%)
#
#
# Test set: Average loss: 0.0059, Accuracy: 8127/10000 (81.3%)
#
# One epoch time cost: 51.353 s
#
# -----------------------------------------------
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.003554
# Train Epoch: 14 [12800/50000 (25.6%)]	Loss: 0.004467
# Train Epoch: 14 [25600/50000 (51.2%)]	Loss: 0.002911
# Train Epoch: 14 [38400/50000 (76.7%)]	Loss: 0.003240
#
# Training Set: Average loss: 0.0035,Accuracy: 42315/50000 (84.6%)
#
#
# Test set: Average loss: 0.0062, Accuracy: 7900/10000 (79.0%)
#
# One epoch time cost: 51.368 s
#
# -----------------------------------------------
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.003151
# Train Epoch: 15 [12800/50000 (25.6%)]	Loss: 0.002920
# Train Epoch: 15 [25600/50000 (51.2%)]	Loss: 0.002051
# Train Epoch: 15 [38400/50000 (76.7%)]	Loss: 0.002606
#
# Training Set: Average loss: 0.0035,Accuracy: 42386/50000 (84.8%)
#
#
# Test set: Average loss: 0.0075, Accuracy: 7507/10000 (75.1%)
#
# One epoch time cost: 51.343 s
#
# -----------------------------------------------
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.003711
# Train Epoch: 16 [12800/50000 (25.6%)]	Loss: 0.005707
# Train Epoch: 16 [25600/50000 (51.2%)]	Loss: 0.002979
# Train Epoch: 16 [38400/50000 (76.7%)]	Loss: 0.003722
#
# Training Set: Average loss: 0.0034,Accuracy: 42504/50000 (85.0%)
#
#
# Test set: Average loss: 0.0058, Accuracy: 8008/10000 (80.1%)
#
# One epoch time cost: 51.303 s
#
# -----------------------------------------------
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.002632
# Train Epoch: 17 [12800/50000 (25.6%)]	Loss: 0.003914
# Train Epoch: 17 [25600/50000 (51.2%)]	Loss: 0.002628
# Train Epoch: 17 [38400/50000 (76.7%)]	Loss: 0.003658
#
# Training Set: Average loss: 0.0034,Accuracy: 42717/50000 (85.4%)
#
#
# Test set: Average loss: 0.0063, Accuracy: 7926/10000 (79.3%)
#
# One epoch time cost: 51.398 s
#
# -----------------------------------------------
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.003889
# Train Epoch: 18 [12800/50000 (25.6%)]	Loss: 0.003174
# Train Epoch: 18 [25600/50000 (51.2%)]	Loss: 0.003039
# Train Epoch: 18 [38400/50000 (76.7%)]	Loss: 0.003216
#
# Training Set: Average loss: 0.0033,Accuracy: 42766/50000 (85.5%)
#
#
# Test set: Average loss: 0.0059, Accuracy: 8048/10000 (80.5%)
#
# One epoch time cost: 51.355 s
#
# -----------------------------------------------
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.002198
# Train Epoch: 19 [12800/50000 (25.6%)]	Loss: 0.003288
# Train Epoch: 19 [25600/50000 (51.2%)]	Loss: 0.004144
# Train Epoch: 19 [38400/50000 (76.7%)]	Loss: 0.003574
#
# Training Set: Average loss: 0.0032,Accuracy: 42916/50000 (85.8%)
#
#
# Test set: Average loss: 0.0060, Accuracy: 8070/10000 (80.7%)
#
# One epoch time cost: 51.302 s
#
# -----------------------------------------------
#
# Train Epoch: 20 [0/50000 (0.0%)]	Loss: 0.003668
# Train Epoch: 20 [12800/50000 (25.6%)]	Loss: 0.003360
# Train Epoch: 20 [25600/50000 (51.2%)]	Loss: 0.002676
# Train Epoch: 20 [38400/50000 (76.7%)]	Loss: 0.003307
#
# Training Set: Average loss: 0.0032,Accuracy: 42974/50000 (85.9%)
#
#
# Test set: Average loss: 0.0057, Accuracy: 8148/10000 (81.5%)
#
# One epoch time cost: 51.333 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 21 [0/50000 (0.0%)]	Loss: 0.002246
# Train Epoch: 21 [12800/50000 (25.6%)]	Loss: 0.003710
# Train Epoch: 21 [25600/50000 (51.2%)]	Loss: 0.002174
# Train Epoch: 21 [38400/50000 (76.7%)]	Loss: 0.004628
#
# Training Set: Average loss: 0.0032,Accuracy: 43041/50000 (86.1%)
#
#
# Test set: Average loss: 0.0068, Accuracy: 7850/10000 (78.5%)
#
# One epoch time cost: 51.302 s
#
# -----------------------------------------------
#
# Train Epoch: 22 [0/50000 (0.0%)]	Loss: 0.002329
# Train Epoch: 22 [12800/50000 (25.6%)]	Loss: 0.003271
# Train Epoch: 22 [25600/50000 (51.2%)]	Loss: 0.003213
# Train Epoch: 22 [38400/50000 (76.7%)]	Loss: 0.003634
#
# Training Set: Average loss: 0.0031,Accuracy: 43184/50000 (86.4%)
#
#
# Test set: Average loss: 0.0068, Accuracy: 7864/10000 (78.6%)
#
# One epoch time cost: 51.299 s
#
# -----------------------------------------------
#
# Train Epoch: 23 [0/50000 (0.0%)]	Loss: 0.003780
# Train Epoch: 23 [12800/50000 (25.6%)]	Loss: 0.002718
# Train Epoch: 23 [25600/50000 (51.2%)]	Loss: 0.002542
# Train Epoch: 23 [38400/50000 (76.7%)]	Loss: 0.002436
#
# Training Set: Average loss: 0.0031,Accuracy: 43079/50000 (86.2%)
#
#
# Test set: Average loss: 0.0054, Accuracy: 8257/10000 (82.6%)
#
# One epoch time cost: 51.347 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 24 [0/50000 (0.0%)]	Loss: 0.004002
# Train Epoch: 24 [12800/50000 (25.6%)]	Loss: 0.002568
# Train Epoch: 24 [25600/50000 (51.2%)]	Loss: 0.003224
# Train Epoch: 24 [38400/50000 (76.7%)]	Loss: 0.003953
#
# Training Set: Average loss: 0.0031,Accuracy: 43114/50000 (86.2%)
#
#
# Test set: Average loss: 0.0062, Accuracy: 8044/10000 (80.4%)
#
# One epoch time cost: 51.352 s
#
# -----------------------------------------------
#
# Train Epoch: 25 [0/50000 (0.0%)]	Loss: 0.003102
# Train Epoch: 25 [12800/50000 (25.6%)]	Loss: 0.002245
# Train Epoch: 25 [25600/50000 (51.2%)]	Loss: 0.003194
# Train Epoch: 25 [38400/50000 (76.7%)]	Loss: 0.003031
#
# Training Set: Average loss: 0.0031,Accuracy: 43209/50000 (86.4%)
#
#
# Test set: Average loss: 0.0046, Accuracy: 8441/10000 (84.4%)
#
# One epoch time cost: 51.411 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 26 [0/50000 (0.0%)]	Loss: 0.002202
# Train Epoch: 26 [12800/50000 (25.6%)]	Loss: 0.003062
# Train Epoch: 26 [25600/50000 (51.2%)]	Loss: 0.003480
# Train Epoch: 26 [38400/50000 (76.7%)]	Loss: 0.002918
#
# Training Set: Average loss: 0.0032,Accuracy: 43149/50000 (86.3%)
#
#
# Test set: Average loss: 0.0051, Accuracy: 8297/10000 (83.0%)
#
# One epoch time cost: 51.391 s
#
# -----------------------------------------------
#
# Train Epoch: 27 [0/50000 (0.0%)]	Loss: 0.002087
# Train Epoch: 27 [12800/50000 (25.6%)]	Loss: 0.003076
# Train Epoch: 27 [25600/50000 (51.2%)]	Loss: 0.004044
# Train Epoch: 27 [38400/50000 (76.7%)]	Loss: 0.003537
#
# Training Set: Average loss: 0.0030,Accuracy: 43352/50000 (86.7%)
#
#
# Test set: Average loss: 0.0058, Accuracy: 8136/10000 (81.4%)
#
# One epoch time cost: 51.488 s
#
# -----------------------------------------------
#
# Train Epoch: 28 [0/50000 (0.0%)]	Loss: 0.003093
# Train Epoch: 28 [12800/50000 (25.6%)]	Loss: 0.003160
# Train Epoch: 28 [25600/50000 (51.2%)]	Loss: 0.003667
# Train Epoch: 28 [38400/50000 (76.7%)]	Loss: 0.003610
#
# Training Set: Average loss: 0.0030,Accuracy: 43286/50000 (86.6%)
#
#
# Test set: Average loss: 0.0050, Accuracy: 8294/10000 (82.9%)
#
# One epoch time cost: 51.490 s
#
# -----------------------------------------------
#
# Train Epoch: 29 [0/50000 (0.0%)]	Loss: 0.002735
# Train Epoch: 29 [12800/50000 (25.6%)]	Loss: 0.004195
# Train Epoch: 29 [25600/50000 (51.2%)]	Loss: 0.002740
# Train Epoch: 29 [38400/50000 (76.7%)]	Loss: 0.003246
#
# Training Set: Average loss: 0.0030,Accuracy: 43409/50000 (86.8%)
#
#
# Test set: Average loss: 0.0055, Accuracy: 8189/10000 (81.9%)
#
# One epoch time cost: 51.518 s
#
# -----------------------------------------------
#
# Train Epoch: 30 [0/50000 (0.0%)]	Loss: 0.001726
# Train Epoch: 30 [12800/50000 (25.6%)]	Loss: 0.001368
# Train Epoch: 30 [25600/50000 (51.2%)]	Loss: 0.002348
# Train Epoch: 30 [38400/50000 (76.7%)]	Loss: 0.001521
#
# Training Set: Average loss: 0.0018,Accuracy: 46112/50000 (92.2%)
#
#
# Test set: Average loss: 0.0025, Accuracy: 9119/10000 (91.2%)
#
# One epoch time cost: 51.422 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 31 [0/50000 (0.0%)]	Loss: 0.000773
# Train Epoch: 31 [12800/50000 (25.6%)]	Loss: 0.001388
# Train Epoch: 31 [25600/50000 (51.2%)]	Loss: 0.001060
# Train Epoch: 31 [38400/50000 (76.7%)]	Loss: 0.001063
#
# Training Set: Average loss: 0.0014,Accuracy: 47066/50000 (94.1%)
#
#
# Test set: Average loss: 0.0024, Accuracy: 9152/10000 (91.5%)
#
# One epoch time cost: 51.358 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 32 [0/50000 (0.0%)]	Loss: 0.001631
# Train Epoch: 32 [12800/50000 (25.6%)]	Loss: 0.001733
# Train Epoch: 32 [25600/50000 (51.2%)]	Loss: 0.001119
# Train Epoch: 32 [38400/50000 (76.7%)]	Loss: 0.000913
#
# Training Set: Average loss: 0.0012,Accuracy: 47418/50000 (94.8%)
#
#
# Test set: Average loss: 0.0024, Accuracy: 9212/10000 (92.1%)
#
# One epoch time cost: 51.307 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 33 [0/50000 (0.0%)]	Loss: 0.000930
# Train Epoch: 33 [12800/50000 (25.6%)]	Loss: 0.000890
# Train Epoch: 33 [25600/50000 (51.2%)]	Loss: 0.000947
# Train Epoch: 33 [38400/50000 (76.7%)]	Loss: 0.000820
#
# Training Set: Average loss: 0.0011,Accuracy: 47671/50000 (95.3%)
#
#
# Test set: Average loss: 0.0024, Accuracy: 9182/10000 (91.8%)
#
# One epoch time cost: 51.293 s
#
# -----------------------------------------------
#
# Train Epoch: 34 [0/50000 (0.0%)]	Loss: 0.000570
# Train Epoch: 34 [12800/50000 (25.6%)]	Loss: 0.000579
# Train Epoch: 34 [25600/50000 (51.2%)]	Loss: 0.001397
# Train Epoch: 34 [38400/50000 (76.7%)]	Loss: 0.001201
#
# Training Set: Average loss: 0.0010,Accuracy: 47941/50000 (95.9%)
#
#
# Test set: Average loss: 0.0024, Accuracy: 9188/10000 (91.9%)
#
# One epoch time cost: 51.252 s
#
# -----------------------------------------------
#
# Train Epoch: 35 [0/50000 (0.0%)]	Loss: 0.000527
# Train Epoch: 35 [12800/50000 (25.6%)]	Loss: 0.000399
# Train Epoch: 35 [25600/50000 (51.2%)]	Loss: 0.000369
# Train Epoch: 35 [38400/50000 (76.7%)]	Loss: 0.000968
#
# Training Set: Average loss: 0.0009,Accuracy: 48065/50000 (96.1%)
#
#
# Test set: Average loss: 0.0024, Accuracy: 9207/10000 (92.1%)
#
# One epoch time cost: 51.294 s
#
# -----------------------------------------------
#
# Train Epoch: 36 [0/50000 (0.0%)]	Loss: 0.000516
# Train Epoch: 36 [12800/50000 (25.6%)]	Loss: 0.000625
# Train Epoch: 36 [25600/50000 (51.2%)]	Loss: 0.000626
# Train Epoch: 36 [38400/50000 (76.7%)]	Loss: 0.000766
#
# Training Set: Average loss: 0.0008,Accuracy: 48270/50000 (96.5%)
#
#
# Test set: Average loss: 0.0025, Accuracy: 9176/10000 (91.8%)
#
# One epoch time cost: 51.367 s
#
# -----------------------------------------------
#
# Train Epoch: 37 [0/50000 (0.0%)]	Loss: 0.000824
# Train Epoch: 37 [12800/50000 (25.6%)]	Loss: 0.000653
# Train Epoch: 37 [25600/50000 (51.2%)]	Loss: 0.000739
# Train Epoch: 37 [38400/50000 (76.7%)]	Loss: 0.001513
#
# Training Set: Average loss: 0.0007,Accuracy: 48377/50000 (96.8%)
#
#
# Test set: Average loss: 0.0025, Accuracy: 9187/10000 (91.9%)
#
# One epoch time cost: 51.333 s
#
# -----------------------------------------------
#
# Train Epoch: 38 [0/50000 (0.0%)]	Loss: 0.000737
# Train Epoch: 38 [12800/50000 (25.6%)]	Loss: 0.000835
# Train Epoch: 38 [25600/50000 (51.2%)]	Loss: 0.000743
# Train Epoch: 38 [38400/50000 (76.7%)]	Loss: 0.001019
#
# Training Set: Average loss: 0.0007,Accuracy: 48474/50000 (96.9%)
#
#
# Test set: Average loss: 0.0025, Accuracy: 9255/10000 (92.5%)
#
# One epoch time cost: 51.351 s
#
#
# !!!!!!!!!!!!!!!!! NEW BEST ACC !!!!!!!!!!!!!
#
# -----------------------------------------------
#
# Train Epoch: 39 [0/50000 (0.0%)]	Loss: 0.000277
# Train Epoch: 39 [12800/50000 (25.6%)]	Loss: 0.000440
# Train Epoch: 39 [25600/50000 (51.2%)]	Loss: 0.000855
# Train Epoch: 39 [38400/50000 (76.7%)]	Loss: 0.000493
#
# Training Set: Average loss: 0.0007,Accuracy: 48612/50000 (97.2%)
#
#
# Test set: Average loss: 0.0025, Accuracy: 9237/10000 (92.4%)
#
# One epoch time cost: 51.340 s
#
# -----------------------------------------------
#
# Train Epoch: 40 [0/50000 (0.0%)]	Loss: 0.000544
# Train Epoch: 40 [12800/50000 (25.6%)]	Loss: 0.001047
# Train Epoch: 40 [25600/50000 (51.2%)]	Loss: 0.001191
# Train Epoch: 40 [38400/50000 (76.7%)]	Loss: 0.000397
#
# Training Set: Average loss: 0.0006,Accuracy: 48738/50000 (97.5%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 9231/10000 (92.3%)
#
# One epoch time cost: 51.373 s
#
# -----------------------------------------------
#
# Train Epoch: 41 [0/50000 (0.0%)]	Loss: 0.000381
# Train Epoch: 41 [12800/50000 (25.6%)]	Loss: 0.000430
# Train Epoch: 41 [25600/50000 (51.2%)]	Loss: 0.000686
# Train Epoch: 41 [38400/50000 (76.7%)]	Loss: 0.000962
#
# Training Set: Average loss: 0.0006,Accuracy: 48720/50000 (97.4%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9179/10000 (91.8%)
#
# One epoch time cost: 51.384 s
#
# -----------------------------------------------
#
# Train Epoch: 42 [0/50000 (0.0%)]	Loss: 0.000494
# Train Epoch: 42 [12800/50000 (25.6%)]	Loss: 0.000395
# Train Epoch: 42 [25600/50000 (51.2%)]	Loss: 0.000883
# Train Epoch: 42 [38400/50000 (76.7%)]	Loss: 0.000397
#
# Training Set: Average loss: 0.0006,Accuracy: 48748/50000 (97.5%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9211/10000 (92.1%)
#
# One epoch time cost: 51.375 s
#
# -----------------------------------------------
#
# Train Epoch: 43 [0/50000 (0.0%)]	Loss: 0.000410
# Train Epoch: 43 [12800/50000 (25.6%)]	Loss: 0.000899
# Train Epoch: 43 [25600/50000 (51.2%)]	Loss: 0.000512
# Train Epoch: 43 [38400/50000 (76.7%)]	Loss: 0.000583
#
# Training Set: Average loss: 0.0005,Accuracy: 48831/50000 (97.7%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9242/10000 (92.4%)
#
# One epoch time cost: 51.411 s
#
# -----------------------------------------------
#
# Train Epoch: 44 [0/50000 (0.0%)]	Loss: 0.000152
# Train Epoch: 44 [12800/50000 (25.6%)]	Loss: 0.000439
# Train Epoch: 44 [25600/50000 (51.2%)]	Loss: 0.000515
# Train Epoch: 44 [38400/50000 (76.7%)]	Loss: 0.000519
#
# Training Set: Average loss: 0.0005,Accuracy: 48878/50000 (97.8%)
#
#
# Test set: Average loss: 0.0027, Accuracy: 9245/10000 (92.4%)
#
# One epoch time cost: 51.413 s
#
# -----------------------------------------------
#
# Train Epoch: 45 [0/50000 (0.0%)]	Loss: 0.000423
# Train Epoch: 45 [12800/50000 (25.6%)]	Loss: 0.000562
# Train Epoch: 45 [25600/50000 (51.2%)]	Loss: 0.000277
# Train Epoch: 45 [38400/50000 (76.7%)]	Loss: 0.001375
#
# Training Set: Average loss: 0.0005,Accuracy: 48962/50000 (97.9%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9193/10000 (91.9%)
#
# One epoch time cost: 51.394 s
#
# -----------------------------------------------
#
# Train Epoch: 46 [0/50000 (0.0%)]	Loss: 0.000796
# Train Epoch: 46 [12800/50000 (25.6%)]	Loss: 0.000454
# Train Epoch: 46 [25600/50000 (51.2%)]	Loss: 0.000599
# Train Epoch: 46 [38400/50000 (76.7%)]	Loss: 0.000564
#
# Training Set: Average loss: 0.0005,Accuracy: 48929/50000 (97.9%)
#
#
# Test set: Average loss: 0.0030, Accuracy: 9177/10000 (91.8%)
#
# One epoch time cost: 51.464 s
#
# -----------------------------------------------
#
# Train Epoch: 47 [0/50000 (0.0%)]	Loss: 0.000439
# Train Epoch: 47 [12800/50000 (25.6%)]	Loss: 0.000736
# Train Epoch: 47 [25600/50000 (51.2%)]	Loss: 0.000553
# Train Epoch: 47 [38400/50000 (76.7%)]	Loss: 0.000185
#
# Training Set: Average loss: 0.0005,Accuracy: 48965/50000 (97.9%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9205/10000 (92.0%)
#
# One epoch time cost: 51.475 s
#
# -----------------------------------------------
#
# Train Epoch: 48 [0/50000 (0.0%)]	Loss: 0.000355
# Train Epoch: 48 [12800/50000 (25.6%)]	Loss: 0.000182
# Train Epoch: 48 [25600/50000 (51.2%)]	Loss: 0.000420
# Train Epoch: 48 [38400/50000 (76.7%)]	Loss: 0.000764
#
# Training Set: Average loss: 0.0005,Accuracy: 49021/50000 (98.0%)
#
#
# Test set: Average loss: 0.0030, Accuracy: 9166/10000 (91.7%)
#
# One epoch time cost: 51.514 s
#
# -----------------------------------------------
#
# Train Epoch: 49 [0/50000 (0.0%)]	Loss: 0.000429
# Train Epoch: 49 [12800/50000 (25.6%)]	Loss: 0.000347
# Train Epoch: 49 [25600/50000 (51.2%)]	Loss: 0.000595
# Train Epoch: 49 [38400/50000 (76.7%)]	Loss: 0.000362
#
# Training Set: Average loss: 0.0005,Accuracy: 48928/50000 (97.9%)
#
#
# Test set: Average loss: 0.0030, Accuracy: 9179/10000 (91.8%)
#
# One epoch time cost: 51.508 s
#
# -----------------------------------------------
#
# Train Epoch: 50 [0/50000 (0.0%)]	Loss: 0.000329
# Train Epoch: 50 [12800/50000 (25.6%)]	Loss: 0.000408
# Train Epoch: 50 [25600/50000 (51.2%)]	Loss: 0.000527
# Train Epoch: 50 [38400/50000 (76.7%)]	Loss: 0.000325
#
# Training Set: Average loss: 0.0005,Accuracy: 49049/50000 (98.1%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9193/10000 (91.9%)
#
# One epoch time cost: 51.044 s
#
# -----------------------------------------------
#
# Train Epoch: 51 [0/50000 (0.0%)]	Loss: 0.000553
# Train Epoch: 51 [12800/50000 (25.6%)]	Loss: 0.000511
# Train Epoch: 51 [25600/50000 (51.2%)]	Loss: 0.000595
# Train Epoch: 51 [38400/50000 (76.7%)]	Loss: 0.000445
#
# Training Set: Average loss: 0.0005,Accuracy: 49010/50000 (98.0%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 9185/10000 (91.8%)
#
# One epoch time cost: 50.899 s
#
# -----------------------------------------------
#
# Train Epoch: 52 [0/50000 (0.0%)]	Loss: 0.000328
# Train Epoch: 52 [12800/50000 (25.6%)]	Loss: 0.000674
# Train Epoch: 52 [25600/50000 (51.2%)]	Loss: 0.000436
# Train Epoch: 52 [38400/50000 (76.7%)]	Loss: 0.000603
#
# Training Set: Average loss: 0.0005,Accuracy: 48991/50000 (98.0%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 9183/10000 (91.8%)
#
# One epoch time cost: 51.100 s
#
# -----------------------------------------------
#
# Train Epoch: 53 [0/50000 (0.0%)]	Loss: 0.000514
# Train Epoch: 53 [12800/50000 (25.6%)]	Loss: 0.000642
# Train Epoch: 53 [25600/50000 (51.2%)]	Loss: 0.000244
# Train Epoch: 53 [38400/50000 (76.7%)]	Loss: 0.000271
#
# Training Set: Average loss: 0.0005,Accuracy: 48948/50000 (97.9%)
#
#
# Test set: Average loss: 0.0030, Accuracy: 9198/10000 (92.0%)
#
# One epoch time cost: 50.883 s
#
# -----------------------------------------------
#
# Train Epoch: 54 [0/50000 (0.0%)]	Loss: 0.000390
# Train Epoch: 54 [12800/50000 (25.6%)]	Loss: 0.000704
# Train Epoch: 54 [25600/50000 (51.2%)]	Loss: 0.000148
# Train Epoch: 54 [38400/50000 (76.7%)]	Loss: 0.001327
#
# Training Set: Average loss: 0.0004,Accuracy: 49106/50000 (98.2%)
#
#
# Test set: Average loss: 0.0032, Accuracy: 9120/10000 (91.2%)
#
# One epoch time cost: 51.293 s
#
# -----------------------------------------------
#
# Train Epoch: 55 [0/50000 (0.0%)]	Loss: 0.000378
# Train Epoch: 55 [12800/50000 (25.6%)]	Loss: 0.000500
# Train Epoch: 55 [25600/50000 (51.2%)]	Loss: 0.000420
# Train Epoch: 55 [38400/50000 (76.7%)]	Loss: 0.000725
#
# Training Set: Average loss: 0.0005,Accuracy: 49002/50000 (98.0%)
#
#
# Test set: Average loss: 0.0030, Accuracy: 9118/10000 (91.2%)
#
# One epoch time cost: 50.849 s
#
# -----------------------------------------------
#
# Train Epoch: 56 [0/50000 (0.0%)]	Loss: 0.000228
# Train Epoch: 56 [12800/50000 (25.6%)]	Loss: 0.000462
# Train Epoch: 56 [25600/50000 (51.2%)]	Loss: 0.000237
# Train Epoch: 56 [38400/50000 (76.7%)]	Loss: 0.000325
#
# Training Set: Average loss: 0.0005,Accuracy: 49009/50000 (98.0%)
#
#
# Test set: Average loss: 0.0033, Accuracy: 9100/10000 (91.0%)
#
# One epoch time cost: 51.148 s
#
# -----------------------------------------------
#
# Train Epoch: 57 [0/50000 (0.0%)]	Loss: 0.000152
# Train Epoch: 57 [12800/50000 (25.6%)]	Loss: 0.000202
# Train Epoch: 57 [25600/50000 (51.2%)]	Loss: 0.000553
# Train Epoch: 57 [38400/50000 (76.7%)]	Loss: 0.000532
#
# Training Set: Average loss: 0.0004,Accuracy: 49069/50000 (98.1%)
#
#
# Test set: Average loss: 0.0031, Accuracy: 9130/10000 (91.3%)
#
# One epoch time cost: 50.866 s
#
# -----------------------------------------------
#
# Train Epoch: 58 [0/50000 (0.0%)]	Loss: 0.000698
